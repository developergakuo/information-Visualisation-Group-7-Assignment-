# %% [markdown]
# # GROUP 7_ INFOVIZ PROJECT
#
# ## An attempt to process and visualise the dataset_2021
#
# # TODO: Visualise most used programming language per country on a map along with average salary per user, age, gender
#
# ## Preprocessing
#
# 1. Eliminate unnecessary columns from our dataset
# 2. Rename columns to make them more understandable
# 3. Change column dtypes where necessary
# 4. Delete rows without any info on Programming language used
# 5. Calculate the average salary per user in a country (Men/or women)
# 6. Gender?

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("survey_results_public_2021.csv")

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
# 5           6             I am a student who is learning to code
# 6           7                        I code primarily as a hobby
# 7           8             I am a student who is learning to code
# 8           9                     I am a developer by profession
# 9          10                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df.shape
# Out:
# (83439, 48)

# %%
df.info
# Out:
# <bound method DataFrame.info of        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# ...

# %%
df.dtypes
# Out:
# ResponseId                        int64
# MainBranch                       object
# Employment                       object
# Country                          object
# US_State                         object
# UK_Country                       object
# EdLevel                          object
# Age1stCode                       object
# LearnCode                        object
# YearsCode                        object
# YearsCodePro                     object
# DevType                          object
# OrgSize                          object
# Currency                         object
# CompTotal                       float64
# CompFreq                         object
# LanguageHaveWorkedWith           object
# LanguageWantToWorkWith           object
# DatabaseHaveWorkedWith           object
# DatabaseWantToWorkWith           object
# PlatformHaveWorkedWith           object
# PlatformWantToWorkWith           object
# WebframeHaveWorkedWith           object
# ...

# %%
# rename a couple of columns
df.rename(columns = {'CompTotal':'GrossSalary','EdLevel':'EducationLevel','LearnCode':'LearnedHowToCode'})
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df = df.rename(columns = {'CompTotal':'GrossSalary','EdLevel':'EducationLevel','LearnCode':'LearnedHowToCode'})

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EducationLevel', 'Age1stCode', 'LearnedHowToCode',
#        'YearsCode', 'YearsCodePro', 'DevType', 'OrgSize', 'Currency',
#        'GrossSalary', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSys', 'NEWStuck', 'NEWSOSites',
#        'SOVisitFreq', 'SOAccount', 'SOPartFreq', 'SOComm', 'NEWOtherComms',
#        'Age', 'Gender', 'Trans', 'Sexuality', 'Ethnicity', 'Accessibility',
#        'MentalHealth', 'SurveyLength', 'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df = df.rename(columns = {'LanguageHaveWorkedWith':'ProgLanguageUsed'})

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EducationLevel', 'Age1stCode', 'LearnedHowToCode',
#        'YearsCode', 'YearsCodePro', 'DevType', 'OrgSize', 'Currency',
#        'GrossSalary', 'CompFreq', 'ProgLanguageUsed', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df.isnull()
# Out:
#        ResponseId  MainBranch  Employment  Country  US_State  UK_Country  \
# 0           False       False       False    False      True        True
# 1           False       False       False    False      True        True
# 2           False       False       False    False      True        True
# 3           False       False       False    False      True        True
# 4           False       False       False    False      True       False
# ...           ...         ...         ...      ...       ...         ...
# 83434       False       False       False    False     False        True
# 83435       False       False       False    False      True        True
# 83436       False       False       False    False     False        True
# 83437       False       False       False    False      True        True
# 83438       False       False       False    False      True        True
#
#        EducationLevel  Age1stCode  LearnedHowToCode  YearsCode  ...    Age  \
# ...

# %%
df.isnull().any()
# Out:
# ResponseId                      False
# MainBranch                      False
# Employment                       True
# Country                         False
# US_State                         True
# UK_Country                       True
# EducationLevel                   True
# Age1stCode                       True
# LearnedHowToCode                 True
# YearsCode                        True
# YearsCodePro                     True
# DevType                          True
# OrgSize                          True
# Currency                         True
# GrossSalary                      True
# CompFreq                         True
# ProgLanguageUsed                 True
# LanguageWantToWorkWith           True
# DatabaseHaveWorkedWith           True
# DatabaseWantToWorkWith           True
# PlatformHaveWorkedWith           True
# PlatformWantToWorkWith           True
# WebframeHaveWorkedWith           True
# WebframeWantToWorkWith           True
# MiscTechHaveWorkedWith           True
# ...

# %%
df.isnull().any().count()
# Out:
# 48

# %%
df.isnull().sum()
# Out:
# ResponseId                          0
# MainBranch                          0
# Employment                        116
# Country                             0
# US_State                        68519
# UK_Country                      79021
# EducationLevel                    313
# Age1stCode                        196
# LearnedHowToCode                  476
# YearsCode                        1798
# YearsCodePro                    22223
# DevType                         16955
# OrgSize                         22713
# Currency                        22359
# GrossSalary                     36256
# CompFreq                        31289
# ProgLanguageUsed                 1082
# LanguageWantToWorkWith           6618
# DatabaseHaveWorkedWith          13893
# DatabaseWantToWorkWith          25140
# PlatformHaveWorkedWith          31304
# PlatformWantToWorkWith          41820
# WebframeHaveWorkedWith          21732
# WebframeWantToWorkWith          31344
# MiscTechHaveWorkedWith          36384
# ...

# %%
columns_needed = ['Country','EducationLevel','LearnedHowToCode','GrossSalary','ProgLanguageUsed','Age','Gender']

# %%
New_df = df[columns_needed].copy()

# %%
New_df
# Out:
#                                                  Country  \
# 0                                               Slovakia
# 1                                            Netherlands
# 2                                     Russian Federation
# 3                                                Austria
# 4      United Kingdom of Great Britain and Northern I...
# ...                                                  ...
# 83434                           United States of America
# 83435                                              Benin
# 83436                           United States of America
# 83437                                             Canada
# 83438                                             Brazil
#
#                                           EducationLevel  \
# 0      Secondary school (e.g. American high school, G...
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
New_df.columns
# Out:
# Index(['Country', 'EducationLevel', 'LearnedHowToCode', 'GrossSalary',
#        'ProgLanguageUsed', 'Age', 'Gender'],
#       dtype='object')

# %%
New_df.shape
# Out:
# (83439, 7)

# %%
New_df['ProgLanguageUsed'].isnull().sum()
# Out:
# 1082

# %%
New_df['ProgLanguageUsed'].dropna(axis=0)
# Out:
# 0        C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                    JavaScript;Python
# 2                             Assembly;C;Python;R;Rust
# 3                                JavaScript;TypeScript
# 4                       Bash/Shell;HTML/CSS;Python;SQL
#                              ...
# 83433    Java;JavaScript;Kotlin;Objective-C;TypeScript
# 83434                               Clojure;Kotlin;SQL
# 83436                               Groovy;Java;Python
# 83437             Bash/Shell;JavaScript;Node.js;Python
# 83438           Delphi;Elixir;HTML/CSS;Java;JavaScript
# Name: ProgLanguageUsed, Length: 82357, dtype: object

# %%
New_df
# Out:
#                                                  Country  \
# 0                                               Slovakia
# 1                                            Netherlands
# 2                                     Russian Federation
# 3                                                Austria
# 4      United Kingdom of Great Britain and Northern I...
# ...                                                  ...
# 83434                           United States of America
# 83435                                              Benin
# 83436                           United States of America
# 83437                                             Canada
# 83438                                             Brazil
#
#                                           EducationLevel  \
# 0      Secondary school (e.g. American high school, G...
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
New_df.dropna(subset=['ProgLanguageUsed'])
# Out:
#                                                  Country  \
# 0                                               Slovakia
# 1                                            Netherlands
# 2                                     Russian Federation
# 3                                                Austria
# 4      United Kingdom of Great Britain and Northern I...
# ...                                                  ...
# 83433                                             Brazil
# 83434                           United States of America
# 83436                           United States of America
# 83437                                             Canada
# 83438                                             Brazil
#
#                                           EducationLevel  \
# 0      Secondary school (e.g. American high school, G...
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
New_df
# Out:
#                                                  Country  \
# 0                                               Slovakia
# 1                                            Netherlands
# 2                                     Russian Federation
# 3                                                Austria
# 4      United Kingdom of Great Britain and Northern I...
# ...                                                  ...
# 83434                           United States of America
# 83435                                              Benin
# 83436                           United States of America
# 83437                                             Canada
# 83438                                             Brazil
#
#                                           EducationLevel  \
# 0      Secondary school (e.g. American high school, G...
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
New_df.isnull().sum()
# Out:
# Country                 0
# EducationLevel        313
# LearnedHowToCode      476
# GrossSalary         36256
# ProgLanguageUsed     1082
# Age                  1032
# Gender               1153
# dtype: int64

# %%
#Drop rows where users did not provide their Edlevel, Age range  and ProgLanguage
final_df = New_df.dropna(subset=['ProgLanguageUsed', 'EducationLevel', 'Age'])

# %%
final_df.isnull().sum()
# Out:
# Country                 0
# EducationLevel          0
# LearnedHowToCode      293
# GrossSalary         34323
# ProgLanguageUsed        0
# Age                     0
# Gender                421
# dtype: int64

# %%
#rename the NA values in the gender column to "prefer not to say"
final_df.loc.Gender = final_df.Gender.fillna('prefer not to say')

# %%
final_df.loc.LearnedHowToCode = final_df.LearnedHowToCode.fillna('prefer not to say')

# %%
final_df.isnull().sum()
# Out:
# Country                 0
# EducationLevel          0
# LearnedHowToCode        0
# GrossSalary         34323
# ProgLanguageUsed        0
# Age                     0
# Gender                  0
# dtype: int64

# %%
final_df.shape
# Out:
# (81224, 7)

# %%
final_df.Age
# Out:
# 0        25-34 years old
# 1        18-24 years old
# 2        18-24 years old
# 3        35-44 years old
# 4        25-34 years old
#               ...
# 83433    25-34 years old
# 83434    25-34 years old
# 83436    25-34 years old
# 83437    25-34 years old
# 83438    18-24 years old
# Name: Age, Length: 81224, dtype: object

# %%
#Drop rows in which the user did not specify his/her age range
final_df.drop(final_df.index[final_df['Age'] == "Prefer not to say"])
# Out:
#                                                  Country  \
# 0                                               Slovakia
# 1                                            Netherlands
# 2                                     Russian Federation
# 3                                                Austria
# 4      United Kingdom of Great Britain and Northern I...
# ...                                                  ...
# 83433                                             Brazil
# 83434                           United States of America
# 83436                           United States of America
# 83437                                             Canada
# 83438                                             Brazil
#
#                                           EducationLevel  \
# 0      Secondary school (e.g. American high school, G...
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
final_df['Age'].value_counts()['Prefer not to say']
# Out:
# 534

# %%
final_one_df = final_df.drop(final_df.index[final_df['Age'] == "Prefer not to say"])

# %%
final_one_df.shape
# Out:
# (80690, 7)

# %%
final_one_df.head(5)
# Out:
#                                              Country  \
# 0                                           Slovakia
# 1                                        Netherlands
# 2                                 Russian Federation
# 3                                            Austria
# 4  United Kingdom of Great Britain and Northern I...
#
#                                       EducationLevel  \
# 0  Secondary school (e.g. American high school, G...
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                     LearnedHowToCode  GrossSalary  \
# 0  Coding Bootcamp;Other online resources (ex: vi...       4800.0
# 1  Other online resources (ex: videos, blogs, etc...          NaN
# 2  Other online resources (ex: videos, blogs, etc...          NaN
# ...

# %%
#TODO
#compute the average salary per country and fill the NA values with the mean of these values
#Visualise
