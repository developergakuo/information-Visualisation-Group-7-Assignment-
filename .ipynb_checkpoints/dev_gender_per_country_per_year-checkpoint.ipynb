# %%
import pandas as pd
import numpy as np
import re #Regex lib
from forex_python.converter import CurrencyRates #currencies lib
from datetime import datetime
import matplotlib

# %% [markdown]
# ### Read in the dataframes and create a dict {(year, dataframe)}

# %%
# Create a list of filenames for the datasets
years = [2017, 2018, 2019, 2020]
file_names = ['datasets/{}.csv'.format(year) for year in years]

# Read in the dataframes and create a dict {(year, dataframe)}
data_frames_dict = {}

data_frames_dict[2017] = pd.read_csv('datasets/2017.csv', encoding = "ISO-8859-1").filter(items=['Country', 'Gender']).dropna(thresh=2) 
data_frames_dict[2018] = pd.read_csv('datasets/2018.csv', encoding = "ISO-8859-1").filter(items=['Country',  'Gender']).dropna(thresh=2) 
data_frames_dict[2019] = pd.read_csv('datasets/2019.csv', encoding = "ISO-8859-1").filter (items=['Country',  'Gender']).dropna(thresh=2) 
data_frames_dict[2020] = pd.read_csv('datasets/2020.csv', encoding = "ISO-8859-1").filter (items=['Country',  'Gender']).dropna(thresh=2) 
data_frames_dict[2021] = pd.read_csv('datasets/2020.csv', encoding = "ISO-8859-1").filter (items=['Country',  'Gender']).dropna(thresh=2)
# Out:
# /usr/local/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ### obtain developer types

# %%
for year, df in data_frames_dict.items():
    df['GenderCount'] = pd.Series(np.ones(len(df.Gender)), index=df.index)  
    df = df.groupby(by=['Country','Gender'] , as_index=False).sum()
    df.to_csv(path_or_buf = 'processed_data/gender/{}-gender_count_per_country.csv'.format(year), index=False)
# Out:
# ['Male' 'Female' 'Gender non-conforming' 'Other'
#  'Male; Gender non-conforming' 'Female; Transgender' 'Male; Female'
#  'Male; Other' 'Transgender' 'Transgender; Gender non-conforming'
#  'Female; Gender non-conforming'
#  'Male; Female; Transgender; Gender non-conforming; Other'
#  'Male; Female; Transgender' 'Male; Female; Other'
#  'Male; Female; Transgender; Gender non-conforming' 'Male; Transgender'
#  'Female; Transgender; Gender non-conforming'
#  'Gender non-conforming; Other' 'Male; Female; Gender non-conforming'
#  'Female; Other' 'Male; Transgender; Gender non-conforming'
#  'Transgender; Other' 'Male; Gender non-conforming; Other'
#  'Female; Gender non-conforming; Other'
#  'Male; Female; Gender non-conforming; Other' 'Female; Transgender; Other'
#  'Female; Transgender; Gender non-conforming; Other'
#  'Male; Transgender; Other' 'Male; Female; Transgender; Other']
#           Country                                Gender  GenderCount
# 0     Afghanistan                                Female          1.0
# 1     Afghanistan  Female; Gender non-conforming; Other          1.0
# 2     Afghanistan                                  Male          9.0
# 3     Afghanistan                           Male; Other          1.0
# 4   Aland Islands                                  Male          2.0
# 5   Aland Islands             Male; Female; Transgender          1.0
# 6         Albania                                Female          3.0
# 7         Albania                 Gender non-conforming          1.0
# 8         Albania                                  Male         28.0
# 9         Albania                           Male; Other          1.0
# 10        Albania                                 Other          1.0
# 11        Algeria                                Female          1.0
# 12        Algeria                 Gender non-conforming          1.0
# 13        Algeria                                  Male         15.0
# 14        Algeria                                 Other          1.0
# ['Male' 'Female'
#  'Female;Male;Transgender;Non-binary, genderqueer, or gender non-conforming'
#  'Female;Male' 'Male;Non-binary, genderqueer, or gender non-conforming'
#  'Non-binary, genderqueer, or gender non-conforming' 'Transgender'
#  'Female;Transgender'
#  'Transgender;Non-binary, genderqueer, or gender non-conforming'
#  'Female;Non-binary, genderqueer, or gender non-conforming'
#  'Female;Transgender;Non-binary, genderqueer, or gender non-conforming'
#  'Male;Transgender' 'Female;Male;Transgender'
#  'Female;Male;Non-binary, genderqueer, or gender non-conforming'
#  'Male;Transgender;Non-binary, genderqueer, or gender non-conforming']
#                 Country                                             Gender  \
# 0           Afghanistan                                             Female
# 1           Afghanistan  Female;Male;Transgender;Non-binary, genderquee...
# 2           Afghanistan                                               Male
# 3               Albania                                             Female
# 4               Albania                                               Male
# 5               Algeria                                             Female
# 6               Algeria                                        Female;Male
# 7               Algeria  Female;Male;Transgender;Non-binary, genderquee...
# 8               Algeria                                               Male
# 9               Algeria  Male;Non-binary, genderqueer, or gender non-co...
# 10              Andorra                                             Female
# 11              Andorra                                               Male
# 12               Angola                                               Male
# 13  Antigua and Barbuda                                               Male
# 14            Argentina                                             Female
#
#     GenderCount
# 0           1.0
# 1           1.0
# 2          17.0
# 3           4.0
# 4          45.0
# 5           3.0
# 6           1.0
# 7           1.0
# 8          55.0
# 9           1.0
# 10          1.0
# 11          5.0
# 12          2.0
# 13          1.0
# 14         41.0
# ['Man' 'Woman' 'Non-binary, genderqueer, or gender non-conforming'
#  'Woman;Non-binary, genderqueer, or gender non-conforming'
#  'Woman;Man;Non-binary, genderqueer, or gender non-conforming' 'Woman;Man'
#  'Man;Non-binary, genderqueer, or gender non-conforming']
#         Country                                             Gender  \
# 0   Afghanistan                                                Man
# 1   Afghanistan  Non-binary, genderqueer, or gender non-conforming
# 2   Afghanistan                                              Woman
# 3   Afghanistan  Woman;Man;Non-binary, genderqueer, or gender n...
# 4       Albania                                                Man
# 5       Albania  Non-binary, genderqueer, or gender non-conforming
# 6       Albania                                              Woman
# 7       Algeria                                                Man
# 8       Algeria  Man;Non-binary, genderqueer, or gender non-con...
# 9       Algeria  Non-binary, genderqueer, or gender non-conforming
# 10      Algeria                                              Woman
# 11      Algeria                                          Woman;Man
# 12      Algeria  Woman;Man;Non-binary, genderqueer, or gender n...
# 13      Andorra                                                Man
# 14      Andorra                                              Woman
#
#     GenderCount
# 0          26.0
# 1           1.0
# 2           2.0
# 3           1.0
# 4          70.0
# 5           1.0
# 6          12.0
# 7         107.0
# 8           1.0
# 9           1.0
# 10         12.0
# 11          1.0
# 12          1.0
# 13          4.0
# 14          1.0
# ['Man' 'Woman' 'Man;Non-binary, genderqueer, or gender non-conforming'
#  'Non-binary, genderqueer, or gender non-conforming'
#  'Woman;Non-binary, genderqueer, or gender non-conforming'
#  'Woman;Man;Non-binary, genderqueer, or gender non-conforming' 'Woman;Man']
#                 Country                                             Gender  \
# 0           Afghanistan                                                Man
# 1           Afghanistan  Non-binary, genderqueer, or gender non-conforming
# 2           Afghanistan                                              Woman
# 3           Afghanistan                                          Woman;Man
# 4               Albania                                                Man
# 5               Albania                                              Woman
# 6               Algeria                                                Man
# 7               Algeria  Non-binary, genderqueer, or gender non-conforming
# 8               Algeria                                              Woman
# 9               Andorra                                                Man
# 10               Angola                                                Man
# 11               Angola                                              Woman
# 12  Antigua and Barbuda  Woman;Man;Non-binary, genderqueer, or gender n...
# 13            Argentina                                                Man
# 14            Argentina  Non-binary, genderqueer, or gender non-conforming
#
#     GenderCount
# 0          28.0
# 1           1.0
# 2           4.0
# 3           1.0
# 4          32.0
# 5           1.0
# 6          58.0
# 7           1.0
# 8           5.0
# 9           3.0
# 10          2.0
# 11          1.0
# 12          1.0
# 13        295.0
# 14          1.0
# ['Man' 'Woman' 'Man;Non-binary, genderqueer, or gender non-conforming'
#  'Non-binary, genderqueer, or gender non-conforming'
#  'Woman;Non-binary, genderqueer, or gender non-conforming'
#  'Woman;Man;Non-binary, genderqueer, or gender non-conforming' 'Woman;Man']
#                 Country                                             Gender  \
# 0           Afghanistan                                                Man
# 1           Afghanistan  Non-binary, genderqueer, or gender non-conforming
# 2           Afghanistan                                              Woman
# 3           Afghanistan                                          Woman;Man
# 4               Albania                                                Man
# 5               Albania                                              Woman
# 6               Algeria                                                Man
# 7               Algeria  Non-binary, genderqueer, or gender non-conforming
# 8               Algeria                                              Woman
# 9               Andorra                                                Man
# 10               Angola                                                Man
# 11               Angola                                              Woman
# 12  Antigua and Barbuda  Woman;Man;Non-binary, genderqueer, or gender n...
# 13            Argentina                                                Man
# 14            Argentina  Non-binary, genderqueer, or gender non-conforming
#
#     GenderCount
# 0          28.0
# 1           1.0
# 2           4.0
# 3           1.0
# 4          32.0
# 5           1.0
# 6          58.0
# 7           1.0
# 8           5.0
# 9           3.0
# 10          2.0
# 11          1.0
# 12          1.0
# 13        295.0
# 14          1.0
