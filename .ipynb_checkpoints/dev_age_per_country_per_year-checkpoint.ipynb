# %%
import pandas as pd
import numpy as np
import re #Regex lib
from forex_python.converter import CurrencyRates #currencies lib
from datetime import datetime
import matplotlib
import json

# %% [markdown]
# ### Read in the dataframes and create a dict {(year, dataframe)}

# %%
# Create a list of filenames for the datasets
years = [2017, 2018, 2019, 2020]
file_names = ['datasets/{}.csv'.format(year) for year in years]

# Read in the dataframes and create a dict {(year, dataframe)}
data_frames_dict = {}

#data_frames_dict[2017] = pd.read_csv('datasets/2017.csv', encoding = "ISO-8859-1").filter(items=['Country', 'Age']).dropna(thresh=2) 
data_frames_dict[2018] = pd.read_csv('datasets/2018.csv', encoding = "ISO-8859-1").filter(items=['Country',  'Age']).dropna(thresh=2) 
data_frames_dict[2019] = pd.read_csv('datasets/2019.csv', encoding = "ISO-8859-1").filter (items=['Country',  'Age']).dropna(thresh=2) 
data_frames_dict[2020] = pd.read_csv('datasets/2020.csv', encoding = "ISO-8859-1").filter (items=['Country',  'Age']).dropna(thresh=2) 
data_frames_dict[2021] = pd.read_csv('datasets/2020.csv', encoding = "ISO-8859-1").filter (items=['Country',  'Age']).dropna(thresh=2)

# %%
def age_mapper(age):
    if age < 18:
        return 'Under 18 years old'
    elif age >= 18 and  age<=24:
        return '18 - 24 years old'
    elif age >= 25 and age <= 34:
        return '25 - 34 years old'
    elif age >= 35 and age <=  44:
        return '35 - 44 years old'
    elif age >= 45 and age <= 54: 
        return '45 - 54 years old' 
    elif age >= 55  and age <= 64:
        return '55 - 64 years old'
    elif age >= 65:
        return '65 years or older'
    else:
        raise Exception("Age invalid")

# %% [markdown]
# ### obtain developer types

# %%
for year, df in data_frames_dict.items():
    if year != 2018:
        df.Age = df.Age.apply(lambda x: age_mapper(int(x)))
    df['AgeCount'] = pd.Series(np.ones(len(df.Age)), index=df.index)  
    df = df.groupby(by=['Country','Age'] , as_index=False).sum()

    json_dict = {}
    for k, v in df.groupby('Country'):
        inner_dict = {}
        for age, count in zip(v['Age'], v['AgeCount']):
            inner_dict[age] = count 
        json_dict[k] = inner_dict
        
        
    with open("processed_data/age/{}-age_count_per_country.json".format(year), "w") as outfile:
        json.dump(json_dict, outfile, indent = 4, ensure_ascii=False)

# %%
json_dict
# Out:
# {'Afghanistan': {'18 - 24 years old': 12.0,
#   '25 - 34 years old': 8.0,
#   'Under 18 years old': 2.0},
#  'Albania': {'18 - 24 years old': 12.0,
#   '25 - 34 years old': 13.0,
#   '35 - 44 years old': 4.0,
#   'Under 18 years old': 1.0},
#  'Algeria': {'18 - 24 years old': 18.0,
#   '25 - 34 years old': 24.0,
#   '35 - 44 years old': 6.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 2.0},
#  'Andorra': {'25 - 34 years old': 1.0,
#   '35 - 44 years old': 1.0,
#   '45 - 54 years old': 1.0},
#  'Angola': {'18 - 24 years old': 1.0,
#   '25 - 34 years old': 1.0,
#   '65 years or older': 1.0},
#  'Argentina': {'18 - 24 years old': 68.0,
#   '25 - 34 years old': 122.0,
#   '35 - 44 years old': 80.0,
#   '45 - 54 years old': 11.0,
#   '55 - 64 years old': 12.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 3.0},
#  'Armenia': {'18 - 24 years old': 17.0,
#   '25 - 34 years old': 19.0,
#   '35 - 44 years old': 3.0},
#  'Australia': {'18 - 24 years old': 141.0,
#   '25 - 34 years old': 353.0,
#   '35 - 44 years old': 264.0,
#   '45 - 54 years old': 113.0,
#   '55 - 64 years old': 32.0,
#   '65 years or older': 6.0,
#   'Under 18 years old': 39.0},
#  'Austria': {'18 - 24 years old': 102.0,
#   '25 - 34 years old': 188.0,
#   '35 - 44 years old': 82.0,
#   '45 - 54 years old': 30.0,
#   '55 - 64 years old': 9.0,
#   'Under 18 years old': 21.0},
#  'Azerbaijan': {'18 - 24 years old': 10.0,
#   '25 - 34 years old': 9.0,
#   '35 - 44 years old': 1.0,
#   '45 - 54 years old': 2.0},
#  'Bahamas': {'25 - 34 years old': 1.0, '35 - 44 years old': 1.0},
#  'Bahrain': {'25 - 34 years old': 3.0, '35 - 44 years old': 3.0},
#  'Bangladesh': {'18 - 24 years old': 109.0,
#   '25 - 34 years old': 184.0,
#   '35 - 44 years old': 15.0,
#   '45 - 54 years old': 3.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 11.0},
#  'Barbados': {'18 - 24 years old': 1.0,
#   '25 - 34 years old': 1.0,
#   '35 - 44 years old': 1.0},
#  'Belarus': {'18 - 24 years old': 26.0,
#   '25 - 34 years old': 49.0,
#   '35 - 44 years old': 17.0,
#   '45 - 54 years old': 4.0,
#   'Under 18 years old': 2.0},
#  'Belgium': {'18 - 24 years old': 63.0,
#   '25 - 34 years old': 187.0,
#   '35 - 44 years old': 77.0,
#   '45 - 54 years old': 17.0,
#   '55 - 64 years old': 11.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 6.0},
#  'Belize': {'18 - 24 years old': 2.0, 'Under 18 years old': 1.0},
#  'Benin': {'18 - 24 years old': 2.0,
#   '25 - 34 years old': 2.0,
#   '35 - 44 years old': 1.0},
#  'Bhutan': {'18 - 24 years old': 1.0, '25 - 34 years old': 1.0},
#  'Bolivia': {'18 - 24 years old': 3.0,
#   '25 - 34 years old': 17.0,
#   '35 - 44 years old': 7.0},
#  'Bosnia and Herzegovina': {'18 - 24 years old': 19.0,
#   '25 - 34 years old': 31.0,
#   '35 - 44 years old': 13.0,
#   'Under 18 years old': 3.0},
#  'Botswana': {'18 - 24 years old': 3.0,
#   '25 - 34 years old': 3.0,
#   '35 - 44 years old': 1.0},
#  'Brazil': {'18 - 24 years old': 379.0,
#   '25 - 34 years old': 683.0,
#   '35 - 44 years old': 221.0,
#   '45 - 54 years old': 58.0,
#   '55 - 64 years old': 11.0,
#   '65 years or older': 5.0,
#   'Under 18 years old': 21.0},
#  'Brunei Darussalam': {'18 - 24 years old': 1.0, '25 - 34 years old': 1.0},
#  'Bulgaria': {'18 - 24 years old': 42.0,
#   '25 - 34 years old': 120.0,
#   '35 - 44 years old': 53.0,
#   '45 - 54 years old': 15.0,
#   '55 - 64 years old': 1.0,
#   'Under 18 years old': 10.0},
#  'Burkina Faso': {'18 - 24 years old': 1.0,
#   '25 - 34 years old': 1.0,
#   '45 - 54 years old': 1.0,
#   '55 - 64 years old': 1.0},
#  'Cambodia': {'18 - 24 years old': 7.0,
#   '25 - 34 years old': 4.0,
#   '55 - 64 years old': 1.0},
#  'Cameroon': {'18 - 24 years old': 13.0, '25 - 34 years old': 12.0},
#  'Canada': {'18 - 24 years old': 315.0,
#   '25 - 34 years old': 765.0,
#   '35 - 44 years old': 342.0,
#   '45 - 54 years old': 129.0,
#   '55 - 64 years old': 52.0,
#   '65 years or older': 17.0,
#   'Under 18 years old': 34.0},
#  'Cape Verde': {'35 - 44 years old': 1.0},
#  'Chile': {'18 - 24 years old': 17.0,
#   '25 - 34 years old': 68.0,
#   '35 - 44 years old': 32.0,
#   '45 - 54 years old': 11.0,
#   'Under 18 years old': 2.0},
#  'China': {'18 - 24 years old': 62.0,
#   '25 - 34 years old': 82.0,
#   '35 - 44 years old': 22.0,
#   '45 - 54 years old': 2.0,
#   '55 - 64 years old': 1.0,
#   'Under 18 years old': 9.0},
#  'Colombia': {'18 - 24 years old': 47.0,
#   '25 - 34 years old': 106.0,
#   '35 - 44 years old': 37.0,
#   '45 - 54 years old': 12.0,
#   '55 - 64 years old': 1.0,
#   'Under 18 years old': 3.0},
#  'Congo, Republic of the...': {'25 - 34 years old': 2.0},
#  'Costa Rica': {'18 - 24 years old': 15.0,
#   '25 - 34 years old': 21.0,
#   '35 - 44 years old': 10.0,
#   '45 - 54 years old': 4.0,
#   '55 - 64 years old': 1.0,
#   'Under 18 years old': 1.0},
#  'Croatia': {'18 - 24 years old': 29.0,
#   '25 - 34 years old': 71.0,
#   '35 - 44 years old': 24.0,
#   '45 - 54 years old': 12.0,
#   '55 - 64 years old': 2.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 2.0},
#  'Cuba': {'18 - 24 years old': 4.0,
#   '25 - 34 years old': 9.0,
#   '35 - 44 years old': 2.0},
#  'Cyprus': {'18 - 24 years old': 8.0,
#   '25 - 34 years old': 18.0,
#   '35 - 44 years old': 13.0,
#   '45 - 54 years old': 1.0},
#  'Czech Republic': {'18 - 24 years old': 71.0,
#   '25 - 34 years old': 193.0,
#   '35 - 44 years old': 76.0,
#   '45 - 54 years old': 21.0,
#   '55 - 64 years old': 3.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 18.0},
#  "C̫te d'Ivoire": {'18 - 24 years old': 3.0, '25 - 34 years old': 3.0},
#  'Democratic Republic of the Congo': {'18 - 24 years old': 1.0,
#   '25 - 34 years old': 3.0},
#  'Denmark': {'18 - 24 years old': 53.0,
#   '25 - 34 years old': 143.0,
#   '35 - 44 years old': 76.0,
#   '45 - 54 years old': 24.0,
#   '55 - 64 years old': 13.0,
#   '65 years or older': 4.0,
#   'Under 18 years old': 5.0},
#  'Djibouti': {'25 - 34 years old': 1.0},
#  'Dominican Republic': {'18 - 24 years old': 14.0,
#   '25 - 34 years old': 28.0,
#   '35 - 44 years old': 7.0},
#  'Ecuador': {'18 - 24 years old': 7.0,
#   '25 - 34 years old': 17.0,
#   '35 - 44 years old': 6.0,
#   '45 - 54 years old': 3.0,
#   '55 - 64 years old': 1.0,
#   'Under 18 years old': 2.0},
#  'Egypt': {'18 - 24 years old': 63.0,
#   '25 - 34 years old': 69.0,
#   '35 - 44 years old': 17.0,
#   '45 - 54 years old': 3.0,
#   'Under 18 years old': 9.0},
#  'El Salvador': {'18 - 24 years old': 3.0,
#   '25 - 34 years old': 14.0,
#   '35 - 44 years old': 1.0,
#   '55 - 64 years old': 1.0},
#  'Eritrea': {'25 - 34 years old': 1.0},
#  'Estonia': {'18 - 24 years old': 20.0,
#   '25 - 34 years old': 63.0,
#   '35 - 44 years old': 25.0,
#   '45 - 54 years old': 2.0,
#   'Under 18 years old': 1.0},
#  'Ethiopia': {'18 - 24 years old': 22.0,
#   '25 - 34 years old': 10.0,
#   '35 - 44 years old': 1.0,
#   '65 years or older': 1.0},
#  'Finland': {'18 - 24 years old': 44.0,
#   '25 - 34 years old': 119.0,
#   '35 - 44 years old': 82.0,
#   '45 - 54 years old': 24.0,
#   '55 - 64 years old': 6.0,
#   'Under 18 years old': 8.0},
#  'France': {'18 - 24 years old': 361.0,
#   '25 - 34 years old': 689.0,
#   '35 - 44 years old': 266.0,
#   '45 - 54 years old': 91.0,
#   '55 - 64 years old': 26.0,
#   '65 years or older': 4.0,
#   'Under 18 years old': 33.0},
#  'Gambia': {'18 - 24 years old': 1.0, '25 - 34 years old': 1.0},
#  'Georgia': {'18 - 24 years old': 16.0,
#   '25 - 34 years old': 20.0,
#   '35 - 44 years old': 4.0,
#   '45 - 54 years old': 2.0,
#   'Under 18 years old': 2.0},
#  'Germany': {'18 - 24 years old': 689.0,
#   '25 - 34 years old': 1410.0,
#   '35 - 44 years old': 645.0,
#   '45 - 54 years old': 201.0,
#   '55 - 64 years old': 48.0,
#   '65 years or older': 4.0,
#   'Under 18 years old': 89.0},
#  'Ghana': {'18 - 24 years old': 27.0,
#   '25 - 34 years old': 33.0,
#   '35 - 44 years old': 3.0},
#  'Greece': {'18 - 24 years old': 50.0,
#   '25 - 34 years old': 138.0,
#   '35 - 44 years old': 82.0,
#   '45 - 54 years old': 21.0,
#   '55 - 64 years old': 3.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 12.0},
#  'Guatemala': {'18 - 24 years old': 8.0,
#   '25 - 34 years old': 16.0,
#   '35 - 44 years old': 8.0,
#   '45 - 54 years old': 2.0,
#   '55 - 64 years old': 1.0,
#   'Under 18 years old': 1.0},
#  'Guinea': {'25 - 34 years old': 1.0},
#  'Guyana': {'18 - 24 years old': 2.0, '25 - 34 years old': 1.0},
#  'Haiti': {'25 - 34 years old': 1.0},
#  'Honduras': {'18 - 24 years old': 7.0,
#   '25 - 34 years old': 6.0,
#   '35 - 44 years old': 1.0,
#   '45 - 54 years old': 1.0},
#  'Hong Kong (S.A.R.)': {'18 - 24 years old': 17.0,
#   '25 - 34 years old': 29.0,
#   '35 - 44 years old': 9.0,
#   '45 - 54 years old': 3.0,
#   '55 - 64 years old': 1.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 6.0},
#  'Hungary': {'18 - 24 years old': 63.0,
#   '25 - 34 years old': 120.0,
#   '35 - 44 years old': 64.0,
#   '45 - 54 years old': 22.0,
#   'Under 18 years old': 13.0},
#  'Iceland': {'18 - 24 years old': 5.0,
#   '25 - 34 years old': 17.0,
#   '35 - 44 years old': 14.0,
#   '45 - 54 years old': 1.0},
#  'India': {'18 - 24 years old': 1858.0,
#   '25 - 34 years old': 2168.0,
#   '35 - 44 years old': 251.0,
#   '45 - 54 years old': 23.0,
#   '55 - 64 years old': 10.0,
#   '65 years or older': 7.0,
#   'Under 18 years old': 96.0},
#  'Indonesia': {'18 - 24 years old': 125.0,
#   '25 - 34 years old': 86.0,
#   '35 - 44 years old': 21.0,
#   '45 - 54 years old': 5.0,
#   'Under 18 years old': 18.0},
#  'Iran': {'18 - 24 years old': 108.0,
#   '25 - 34 years old': 203.0,
#   '35 - 44 years old': 36.0,
#   '45 - 54 years old': 1.0,
#   '55 - 64 years old': 1.0,
#   'Under 18 years old': 7.0},
#  'Iraq': {'18 - 24 years old': 10.0,
#   '25 - 34 years old': 8.0,
#   '35 - 44 years old': 1.0},
#  'Ireland': {'18 - 24 years old': 56.0,
#   '25 - 34 years old': 142.0,
#   '35 - 44 years old': 83.0,
#   '45 - 54 years old': 22.0,
#   '55 - 64 years old': 5.0,
#   'Under 18 years old': 2.0},
#  'Isle of Man': {'18 - 24 years old': 3.0,
#   '25 - 34 years old': 1.0,
#   '45 - 54 years old': 1.0},
#  'Israel': {'18 - 24 years old': 79.0,
#   '25 - 34 years old': 192.0,
#   '35 - 44 years old': 132.0,
#   '45 - 54 years old': 35.0,
#   '55 - 64 years old': 13.0,
#   '65 years or older': 4.0,
#   'Under 18 years old': 24.0},
#  'Italy': {'18 - 24 years old': 165.0,
#   '25 - 34 years old': 364.0,
#   '35 - 44 years old': 210.0,
#   '45 - 54 years old': 75.0,
#   '55 - 64 years old': 21.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 20.0},
#  'Jamaica': {'18 - 24 years old': 4.0,
#   '25 - 34 years old': 4.0,
#   '35 - 44 years old': 2.0,
#   '45 - 54 years old': 1.0},
#  'Japan': {'18 - 24 years old': 18.0,
#   '25 - 34 years old': 123.0,
#   '35 - 44 years old': 43.0,
#   '45 - 54 years old': 13.0,
#   '55 - 64 years old': 2.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 3.0},
#  'Jordan': {'18 - 24 years old': 10.0,
#   '25 - 34 years old': 23.0,
#   '35 - 44 years old': 2.0,
#   'Under 18 years old': 2.0},
#  'Kazakhstan': {'18 - 24 years old': 9.0,
#   '25 - 34 years old': 22.0,
#   '35 - 44 years old': 8.0,
#   '45 - 54 years old': 1.0,
#   '55 - 64 years old': 1.0,
#   'Under 18 years old': 2.0},
#  'Kenya': {'18 - 24 years old': 89.0,
#   '25 - 34 years old': 74.0,
#   '35 - 44 years old': 3.0,
#   '45 - 54 years old': 6.0},
#  'Kosovo': {'18 - 24 years old': 8.0,
#   '25 - 34 years old': 10.0,
#   '35 - 44 years old': 1.0},
#  'Kuwait': {'18 - 24 years old': 2.0,
#   '25 - 34 years old': 4.0,
#   '35 - 44 years old': 1.0,
#   '45 - 54 years old': 1.0,
#   'Under 18 years old': 1.0},
#  'Kyrgyzstan': {'18 - 24 years old': 8.0,
#   '25 - 34 years old': 4.0,
#   '35 - 44 years old': 2.0,
#   '65 years or older': 1.0},
#  "Lao People's Democratic Republic": {'18 - 24 years old': 1.0,
#   '25 - 34 years old': 1.0,
#   '45 - 54 years old': 1.0,
#   '55 - 64 years old': 1.0},
#  'Latvia': {'18 - 24 years old': 26.0,
#   '25 - 34 years old': 51.0,
#   '35 - 44 years old': 15.0,
#   '45 - 54 years old': 1.0},
#  'Lebanon': {'18 - 24 years old': 22.0,
#   '25 - 34 years old': 26.0,
#   '35 - 44 years old': 4.0,
#   '45 - 54 years old': 1.0,
#   'Under 18 years old': 2.0},
#  'Lesotho': {'25 - 34 years old': 1.0},
#  'Libyan Arab Jamahiriya': {'18 - 24 years old': 1.0},
#  'Lithuania': {'18 - 24 years old': 29.0,
#   '25 - 34 years old': 76.0,
#   '35 - 44 years old': 23.0,
#   '45 - 54 years old': 2.0,
#   '55 - 64 years old': 1.0,
#   '65 years or older': 2.0,
#   'Under 18 years old': 7.0},
#  'Luxembourg': {'18 - 24 years old': 2.0,
#   '25 - 34 years old': 12.0,
#   '35 - 44 years old': 12.0,
#   '45 - 54 years old': 2.0,
#   '55 - 64 years old': 1.0,
#   'Under 18 years old': 3.0},
#  'Madagascar': {'18 - 24 years old': 5.0,
#   '25 - 34 years old': 8.0,
#   '45 - 54 years old': 1.0,
#   '55 - 64 years old': 1.0},
#  'Malawi': {'18 - 24 years old': 1.0, '25 - 34 years old': 2.0},
#  'Malaysia': {'18 - 24 years old': 36.0,
#   '25 - 34 years old': 83.0,
#   '35 - 44 years old': 15.0,
#   '45 - 54 years old': 1.0,
#   '55 - 64 years old': 1.0,
#   '65 years or older': 2.0,
#   'Under 18 years old': 3.0},
#  'Maldives': {'25 - 34 years old': 1.0, 'Under 18 years old': 2.0},
#  'Malta': {'18 - 24 years old': 10.0,
#   '25 - 34 years old': 18.0,
#   '35 - 44 years old': 8.0,
#   'Under 18 years old': 1.0},
#  'Mauritania': {'18 - 24 years old': 1.0},
#  'Mauritius': {'18 - 24 years old': 4.0,
#   '25 - 34 years old': 7.0,
#   'Under 18 years old': 1.0},
#  'Mexico': {'18 - 24 years old': 99.0,
#   '25 - 34 years old': 220.0,
#   '35 - 44 years old': 57.0,
#   '45 - 54 years old': 13.0,
#   '55 - 64 years old': 5.0,
#   'Under 18 years old': 5.0},
#  'Monaco': {'25 - 34 years old': 1.0},
#  'Mongolia': {'18 - 24 years old': 3.0, '25 - 34 years old': 3.0},
#  'Montenegro': {'18 - 24 years old': 2.0,
#   '25 - 34 years old': 6.0,
#   '35 - 44 years old': 5.0},
#  'Morocco': {'18 - 24 years old': 50.0,
#   '25 - 34 years old': 32.0,
#   '35 - 44 years old': 3.0,
#   '65 years or older': 1.0},
#  'Mozambique': {'18 - 24 years old': 2.0, '25 - 34 years old': 3.0},
#  'Myanmar': {'18 - 24 years old': 18.0,
#   '25 - 34 years old': 10.0,
#   'Under 18 years old': 1.0},
#  'Namibia': {'18 - 24 years old': 1.0, '25 - 34 years old': 2.0},
#  'Nauru': {'18 - 24 years old': 1.0},
#  'Nepal': {'18 - 24 years old': 86.0,
#   '25 - 34 years old': 52.0,
#   '35 - 44 years old': 4.0,
#   '45 - 54 years old': 1.0,
#   'Under 18 years old': 2.0},
#  'Netherlands': {'18 - 24 years old': 231.0,
#   '25 - 34 years old': 485.0,
#   '35 - 44 years old': 231.0,
#   '45 - 54 years old': 61.0,
#   '55 - 64 years old': 37.0,
#   '65 years or older': 12.0,
#   'Under 18 years old': 23.0},
#  'New Zealand': {'18 - 24 years old': 57.0,
#   '25 - 34 years old': 95.0,
#   '35 - 44 years old': 55.0,
#   '45 - 54 years old': 37.0,
#   '55 - 64 years old': 12.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 15.0},
#  'Nicaragua': {'18 - 24 years old': 4.0,
#   '25 - 34 years old': 15.0,
#   '35 - 44 years old': 5.0,
#   '45 - 54 years old': 2.0},
#  'Niger': {'18 - 24 years old': 1.0, '35 - 44 years old': 1.0},
#  'Nigeria': {'18 - 24 years old': 141.0,
#   '25 - 34 years old': 162.0,
#   '35 - 44 years old': 28.0,
#   '45 - 54 years old': 3.0,
#   'Under 18 years old': 15.0},
#  'Nomadic': {'25 - 34 years old': 9.0,
#   '35 - 44 years old': 4.0,
#   '45 - 54 years old': 1.0},
#  'Norway': {'18 - 24 years old': 47.0,
#   '25 - 34 years old': 147.0,
#   '35 - 44 years old': 72.0,
#   '45 - 54 years old': 33.0,
#   '55 - 64 years old': 7.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 11.0},
#  'Oman': {'18 - 24 years old': 1.0,
#   '25 - 34 years old': 2.0,
#   'Under 18 years old': 1.0},
#  'Pakistan': {'18 - 24 years old': 203.0,
#   '25 - 34 years old': 239.0,
#   '35 - 44 years old': 22.0,
#   '45 - 54 years old': 2.0,
#   'Under 18 years old': 7.0},
#  'Panama': {'18 - 24 years old': 7.0,
#   '25 - 34 years old': 8.0,
#   '35 - 44 years old': 2.0},
#  'Papua New Guinea': {'25 - 34 years old': 1.0},
#  'Paraguay': {'18 - 24 years old': 4.0,
#   '25 - 34 years old': 10.0,
#   '35 - 44 years old': 2.0},
#  'Peru': {'18 - 24 years old': 28.0,
#   '25 - 34 years old': 33.0,
#   '35 - 44 years old': 9.0,
#   '45 - 54 years old': 2.0},
#  'Philippines': {'18 - 24 years old': 106.0,
#   '25 - 34 years old': 81.0,
#   '35 - 44 years old': 19.0,
#   '45 - 54 years old': 2.0,
#   '55 - 64 years old': 1.0,
#   'Under 18 years old': 5.0},
#  'Poland': {'18 - 24 years old': 226.0,
#   '25 - 34 years old': 558.0,
#   '35 - 44 years old': 169.0,
#   '45 - 54 years old': 19.0,
#   '55 - 64 years old': 3.0,
#   '65 years or older': 2.0,
#   'Under 18 years old': 31.0},
#  'Portugal': {'18 - 24 years old': 67.0,
#   '25 - 34 years old': 145.0,
#   '35 - 44 years old': 64.0,
#   '45 - 54 years old': 17.0,
#   '55 - 64 years old': 5.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 7.0},
#  'Qatar': {'18 - 24 years old': 2.0,
#   '25 - 34 years old': 7.0,
#   '35 - 44 years old': 3.0},
#  'Republic of Korea': {'18 - 24 years old': 12.0,
#   '25 - 34 years old': 15.0,
#   '35 - 44 years old': 11.0,
#   '45 - 54 years old': 5.0,
#   'Under 18 years old': 3.0},
#  'Republic of Moldova': {'18 - 24 years old': 10.0,
#   '25 - 34 years old': 17.0,
#   '35 - 44 years old': 3.0,
#   '45 - 54 years old': 4.0,
#   'Under 18 years old': 4.0},
#  'Romania': {'18 - 24 years old': 98.0,
#   '25 - 34 years old': 222.0,
#   '35 - 44 years old': 102.0,
#   '45 - 54 years old': 11.0,
#   '55 - 64 years old': 2.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 16.0},
#  'Russian Federation': {'18 - 24 years old': 154.0,
#   '25 - 34 years old': 430.0,
#   '35 - 44 years old': 158.0,
#   '45 - 54 years old': 29.0,
#   '55 - 64 years old': 6.0,
#   '65 years or older': 3.0,
#   'Under 18 years old': 30.0},
#  'Rwanda': {'18 - 24 years old': 9.0,
#   '25 - 34 years old': 6.0,
#   '35 - 44 years old': 2.0,
#   'Under 18 years old': 1.0},
#  'Saint Lucia': {'25 - 34 years old': 1.0},
#  'Saint Vincent and the Grenadines': {'35 - 44 years old': 1.0},
#  'San Marino': {'25 - 34 years old': 1.0, '45 - 54 years old': 1.0},
#  'Saudi Arabia': {'18 - 24 years old': 9.0,
#   '25 - 34 years old': 16.0,
#   '35 - 44 years old': 9.0,
#   '45 - 54 years old': 1.0,
#   'Under 18 years old': 3.0},
#  'Senegal': {'18 - 24 years old': 4.0,
#   '25 - 34 years old': 4.0,
#   '65 years or older': 1.0},
#  'Serbia': {'18 - 24 years old': 47.0,
#   '25 - 34 years old': 113.0,
#   '35 - 44 years old': 47.0,
#   '45 - 54 years old': 22.0,
#   '55 - 64 years old': 1.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 6.0},
#  'Sierra Leone': {'18 - 24 years old': 1.0, '25 - 34 years old': 1.0},
#  'Singapore': {'18 - 24 years old': 34.0,
#   '25 - 34 years old': 89.0,
#   '35 - 44 years old': 19.0,
#   '45 - 54 years old': 5.0,
#   '55 - 64 years old': 2.0,
#   'Under 18 years old': 9.0},
#  'Slovakia': {'18 - 24 years old': 35.0,
#   '25 - 34 years old': 63.0,
#   '35 - 44 years old': 30.0,
#   '45 - 54 years old': 5.0,
#   'Under 18 years old': 3.0},
#  'Slovenia': {'18 - 24 years old': 23.0,
#   '25 - 34 years old': 55.0,
#   '35 - 44 years old': 30.0,
#   '45 - 54 years old': 7.0,
#   'Under 18 years old': 3.0},
#  'Solomon Islands': {'25 - 34 years old': 2.0},
#  'Somalia': {'18 - 24 years old': 2.0,
#   '25 - 34 years old': 5.0,
#   'Under 18 years old': 1.0},
#  'South Africa': {'18 - 24 years old': 74.0,
#   '25 - 34 years old': 174.0,
#   '35 - 44 years old': 80.0,
#   '45 - 54 years old': 28.0,
#   '55 - 64 years old': 10.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 4.0},
#  'South Korea': {'18 - 24 years old': 31.0,
#   '25 - 34 years old': 63.0,
#   '35 - 44 years old': 19.0,
#   '45 - 54 years old': 5.0,
#   '55 - 64 years old': 1.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 8.0},
#  'Spain': {'18 - 24 years old': 174.0,
#   '25 - 34 years old': 401.0,
#   '35 - 44 years old': 230.0,
#   '45 - 54 years old': 72.0,
#   '55 - 64 years old': 10.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 6.0},
#  'Sri Lanka': {'18 - 24 years old': 47.0,
#   '25 - 34 years old': 110.0,
#   '35 - 44 years old': 12.0,
#   '45 - 54 years old': 2.0,
#   'Under 18 years old': 4.0},
#  'Sudan': {'18 - 24 years old': 10.0,
#   '25 - 34 years old': 7.0,
#   'Under 18 years old': 1.0},
#  'Swaziland': {'25 - 34 years old': 3.0},
#  'Sweden': {'18 - 24 years old': 88.0,
#   '25 - 34 years old': 315.0,
#   '35 - 44 years old': 190.0,
#   '45 - 54 years old': 76.0,
#   '55 - 64 years old': 14.0,
#   '65 years or older': 4.0,
#   'Under 18 years old': 10.0},
#  'Switzerland': {'18 - 24 years old': 115.0,
#   '25 - 34 years old': 217.0,
#   '35 - 44 years old': 107.0,
#   '45 - 54 years old': 34.0,
#   '55 - 64 years old': 14.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 15.0},
#  'Syrian Arab Republic': {'18 - 24 years old': 4.0,
#   '25 - 34 years old': 5.0,
#   '35 - 44 years old': 2.0},
#  'Taiwan': {'18 - 24 years old': 23.0,
#   '25 - 34 years old': 50.0,
#   '35 - 44 years old': 18.0,
#   '45 - 54 years old': 6.0,
#   '55 - 64 years old': 3.0,
#   'Under 18 years old': 1.0},
#  'Tajikistan': {'18 - 24 years old': 1.0, '25 - 34 years old': 1.0},
#  'Thailand': {'18 - 24 years old': 18.0,
#   '25 - 34 years old': 37.0,
#   '35 - 44 years old': 11.0,
#   '45 - 54 years old': 8.0,
#   'Under 18 years old': 4.0},
#  'The former Yugoslav Republic of Macedonia': {'18 - 24 years old': 7.0,
#   '25 - 34 years old': 14.0,
#   '35 - 44 years old': 5.0,
#   '45 - 54 years old': 1.0},
#  'Timor-Leste': {'18 - 24 years old': 1.0},
#  'Togo': {'18 - 24 years old': 2.0,
#   '25 - 34 years old': 5.0,
#   '35 - 44 years old': 2.0},
#  'Trinidad and Tobago': {'18 - 24 years old': 1.0,
#   '25 - 34 years old': 4.0,
#   '35 - 44 years old': 1.0},
#  'Tunisia': {'18 - 24 years old': 23.0,
#   '25 - 34 years old': 29.0,
#   '35 - 44 years old': 6.0,
#   '45 - 54 years old': 1.0,
#   'Under 18 years old': 3.0},
#  'Turkey': {'18 - 24 years old': 100.0,
#   '25 - 34 years old': 282.0,
#   '35 - 44 years old': 96.0,
#   '45 - 54 years old': 14.0,
#   '55 - 64 years old': 2.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 14.0},
#  'Turkmenistan': {'25 - 34 years old': 1.0},
#  'Uganda': {'18 - 24 years old': 23.0,
#   '25 - 34 years old': 25.0,
#   '35 - 44 years old': 3.0},
#  'Ukraine': {'18 - 24 years old': 97.0,
#   '25 - 34 years old': 179.0,
#   '35 - 44 years old': 78.0,
#   '45 - 54 years old': 15.0,
#   'Under 18 years old': 12.0},
#  'United Arab Emirates': {'18 - 24 years old': 12.0,
#   '25 - 34 years old': 35.0,
#   '35 - 44 years old': 12.0,
#   '45 - 54 years old': 1.0,
#   'Under 18 years old': 4.0},
#  'United Kingdom': {'18 - 24 years old': 528.0,
#   '25 - 34 years old': 1286.0,
#   '35 - 44 years old': 709.0,
#   '45 - 54 years old': 271.0,
#   '55 - 64 years old': 115.0,
#   '65 years or older': 33.0,
#   'Under 18 years old': 84.0},
#  'United Republic of Tanzania': {'18 - 24 years old': 2.0,
#   '25 - 34 years old': 13.0,
#   '45 - 54 years old': 1.0,
#   'Under 18 years old': 1.0},
#  'United States': {'18 - 24 years old': 1547.0,
#   '25 - 34 years old': 4056.0,
#   '35 - 44 years old': 2286.0,
#   '45 - 54 years old': 939.0,
#   '55 - 64 years old': 406.0,
#   '65 years or older': 136.0,
#   'Under 18 years old': 249.0},
#  'Uruguay': {'18 - 24 years old': 13.0,
#   '25 - 34 years old': 40.0,
#   '35 - 44 years old': 19.0,
#   '45 - 54 years old': 5.0,
#   '55 - 64 years old': 3.0,
#   'Under 18 years old': 1.0},
#  'Uzbekistan': {'18 - 24 years old': 10.0,
#   '25 - 34 years old': 8.0,
#   '35 - 44 years old': 2.0},
#  'Venezuela, Bolivarian Republic of...': {'18 - 24 years old': 25.0,
#   '25 - 34 years old': 15.0,
#   '35 - 44 years old': 10.0,
#   '45 - 54 years old': 2.0,
#   '55 - 64 years old': 2.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 1.0},
#  'Viet Nam': {'18 - 24 years old': 73.0,
#   '25 - 34 years old': 66.0,
#   '35 - 44 years old': 13.0,
#   '45 - 54 years old': 2.0,
#   '65 years or older': 1.0,
#   'Under 18 years old': 10.0},
#  'Yemen': {'25 - 34 years old': 1.0, '35 - 44 years old': 1.0},
#  'Zambia': {'18 - 24 years old': 2.0,
#   '25 - 34 years old': 7.0,
#   '45 - 54 years old': 1.0},
#  'Zimbabwe': {'18 - 24 years old': 9.0, '25 - 34 years old': 10.0}}
