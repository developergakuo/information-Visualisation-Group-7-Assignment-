# %%
import pandas as pd
import numpy as np
import re #Regex lib
from forex_python.converter import CurrencyRates #currencies lib
from datetime import datetime
import matplotlib

# %% [markdown]
# ### Read in the dataframes and create a dict {(year, dataframe)}

# %%
# Create a list of filenames for the datasets

data_frames_dict = {}

data_frames_dict[2017] = pd.read_csv('datasets/2017.csv', encoding = "ISO-8859-1").filter(items=['Country', 'Currency',  'Salary', 'YearsCodedJob']).dropna(thresh=4) 
data_frames_dict[2018] = pd.read_csv('datasets/2018.csv', encoding = "ISO-8859-1").filter(items=['Country',  'ConvertedSalary', 'YearsCodingProf']).dropna(thresh=3) 
data_frames_dict[2019] = pd.read_csv('datasets/2019.csv', encoding = "ISO-8859-1").filter (items=['Country',  'CompTotal', 'YearsCodePro']).dropna(thresh=3) 
data_frames_dict[2020] = pd.read_csv('datasets/2020.csv', encoding = "ISO-8859-1").filter (items=['Country',  'CompTotal', 'YearsCodePro']).dropna(thresh=3) 
data_frames_dict[2021] = pd.read_csv('datasets/2021.csv', encoding = "ISO-8859-1").filter (items=['Country','CompTotal', 'YearsCodePro']).dropna(thresh=3) 


#preprocess 2021
def check_countryType(country, US_state, UK_country):
    
    if  isinstance(US_state, str):
        return 'United States'
    elif isinstance(UK_country, str) or country == 'United Kingdom of Great Britain and Northern Ireland':
        return 'United Kingdom'
    else:
        return country


df_2021 = pd.read_csv('datasets/2021.csv', encoding = "ISO-8859-1").filter (items=['Country', 'US_State', 'UK_Country',  'CompTotal', 'YearsCodePro'])
df_2021 = df_2021.dropna(subset = ['CompTotal', 'YearsCodePro'])
df_2021.Country =  df_2021.apply(lambda row : check_countryType(row['Country'],row['US_State'],  
                     row['UK_Country']), axis=1)
df_2021 = df_2021.drop(['US_State', 'UK_Country'], axis = 1).dropna(thresh=3)
data_frames_dict[2021]  = df_2021
# Out:
# /var/folders/h2/9wb_tlwj1bd2smbvq_25k5z4097jdb/T/ipykernel_23831/3941661849.py:6: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames_dict[2018] = pd.read_csv('datasets/2018.csv', encoding = "ISO-8859-1").filter(items=['Country',  'ConvertedSalary', 'YearsCodingProf']).dropna(thresh=3)

# %% [markdown]
# # Section 1: Salary preprocessing

# %% [markdown]
# ### The following currencies were found in the datasets and could not be converted to their equivalent currency symbols

# %%
currency_dict = {'Australian dollars (A$)': 'AUD',
 'Bitcoin (btc)': 'btc',
 'Brazilian reais (R$)': 'BRL',
 'British pounds sterling (Â£)': 'GBP',
 'Canadian dollars (C$)': 'CAD',
 'Chinese yuan renminbi (Â¥)': 'CNY',
 'Euros (â\x82¬)': 'EUR',
 'Indian rupees (?)': 'INR',
 'Japanese yen (Â¥)': 'JPY',
 'Polish zloty (zl)': 'PLN',
 'Russian rubles (?)': 'RUB',
 'Singapore dollars (S$)': 'SGD',
 'South African rands (R)': 'ZAR',
 'Swiss francs': 'CHF',
 'U.S. dollars ($)': 'USD',
 'none\tCook Islands dollar': 'NZD'}

# %% [markdown]
# ### Compute currency symbols and add them to the 'currency_dict'

# %%
#helper function to covert currency to its symbol 
def add_currencies_to_dict(currency, currency_dict):
        currency_symbol = re.findall(r'[ˆA-Z]{3}', currency )

        if currency_symbol:
            # redundnat to add symbol to a dict {symbol -> symbol}but helps to treat all currencies the same
            currency_dict[currency] = currency_symbol[0]
        else:
            if currency not in currency_dict:
                print("WARN: there is no conversion available for this currency {}".format(currency))


# go through the  'CurrencySymbol' column if exists, otherwise 'Currency' 
# add all currencies that are not NaN to the 'currency_dict'
for year , df in data_frames_dict.items():
    
    # Check if Currecny column is present in df
    if 'CurrencySymbol' in df:
        print("{} year dataframe has a 'CurrencySymbol' column ".format(year))
        for currency_symbol in df.CurrencySymbol:
            #check for NaN
            if not pd.isna(currency_symbol):
                # redundnat to add symbol to a dict {symbol -> symbol}but helps to treat all currencies the same
                currency_dict[currency_symbol] = currency_symbol
    elif 'Currency' in df:
        print("{} year dataframe has a 'Currency' column ".format(year))
        for currency in df.Currency:
            #check for NaN
            if not pd.isna(currency):
                # add to dict {currency -> currency_symbol}
                add_currencies_to_dict(currency, currency_dict)
# Out:
# 2017 year dataframe has a 'Currency' column

# %% [markdown]
# ### Preporcess the salary related columns (currency, salary, salary type etc ) for datasets

# %% [markdown]
# #### Auxilliary/helper methods for currency conversions

# %%
def convert_currency(amount, currency, factor):
    return available_currencies_for_conversion[currency] * amount * factor


currency_converter = CurrencyRates()
date = datetime(2017, 12, 31, 18, 36, 28, 151012)

available_currencies_for_conversion = currency_converter.get_rates('EUR', date)

available_currencies_for_conversion['EUR']  = 1

# Take care of outlier salaries 
# max montly income in euros
max_montly_salary = 20000

# minimum mothly income in euros
min_montly_salary = 0

# %%
#Dictionary to hold processed payments/salary dataframes for yeas 2017 - 2021

clean_payment_dataframes_2017_to_2020 ={}

# %% [markdown]
# ### Process 2017 payments

# %%
df_2017 = data_frames_dict[2017]

# annual salary divide by 12
annual_rate = float (1/12)


# for each currency entry, replace it with its currency symbol
df_2017.Currency = df_2017.Currency.apply(lambda x: currency_dict[x])


# Filter out the currencies that we cannot convert
df_2017 = df_2017[df_2017.Currency.apply(lambda c:   c  in available_currencies_for_conversion)]
    
# Covert salary to a euros and divide it by 12  
df_2017['Monthly_Sal_EUR'] = df_2017.apply(lambda row : convert_currency(row['Salary'],
                     row['Currency'], annual_rate), axis = 1)

# drop Currency, Salary columns 
# drop c salaries less than min_salary and greater than max salary 
df_2017 = df_2017.drop(['Currency','Salary' ], axis=1)
df_2017 = df_2017[(df_2017.Monthly_Sal_EUR > min_montly_salary) & (df_2017.Monthly_Sal_EUR < max_montly_salary)]

# process years of experience (find the years in the experience description and take the least number)
df_2017.YearsCodedJob = df_2017.YearsCodedJob.apply(lambda experience:   min(map(lambda s: int(s), re.findall(r'\d+', experience)), default=np.nan))

#rename YearsCodedJob to YearsCodePro
df_2017.columns = df_2017.columns.str.replace("YearsCodedJob","YearsCodePro")

#drop any NA 
df_2017= df_2017.dropna(thresh=3)

clean_payment_dataframes_2017_to_2020[2017] = df_2017
df_2017
# Out:
# /var/folders/h2/9wb_tlwj1bd2smbvq_25k5z4097jdb/T/ipykernel_23831/4268674995.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2017['Monthly_Sal_EUR'] = df_2017.apply(lambda row : convert_currency(row['Salary'],
#               Country  YearsCodePro  Monthly_Sal_EUR
# 2      United Kingdom          20.0      8410.201042
# 14     United Kingdom          20.0      7393.583333
# 17      United States          20.0     12992.416667
# 18      United States           3.0      8245.187500
# 22             Israel           5.0     10070.522100
# ...               ...           ...              ...
# 51371     Netherlands           5.0      6182.795699
# 51378          Cyprus           5.0      8960.573477
# 51382          France           1.0      2688.172043
# 51387   United States           1.0      5796.616667
# 51390   United States           3.0      3997.666667
#
# [10229 rows x 3 columns]

# %% [markdown]
# ### Process 2018 payments

# %%
df_2018 = data_frames_dict[2018]

print(df_2018.head())

# convert the converted annual USD salary to monthly salary 
df_2018['Monthly_Sal_EUR'] = df_2018.apply(
    lambda row : convert_currency(row['ConvertedSalary'],'USD', annual_rate), axis = 1)

# We are no longer interested in the ConvertedSalary
# Also drop outlier salaries 
df_2018 = df_2018.drop('ConvertedSalary', axis=1)[(df_2018.Monthly_Sal_EUR > min_montly_salary) & (df_2018.Monthly_Sal_EUR < max_montly_salary)]

df_2018.YearsCodingProf = df_2018.YearsCodingProf.apply(lambda experience:   min(map(lambda s: int(s), re.findall(r'\d+', experience)), default=np.nan))

# rename YearsCodingProf to YearsCodePro
df_2018.columns = df_2018.columns.str.replace("YearsCodingProf","YearsCodePro")

# drop any NA at this point 
df_2018= df_2018.dropna(thresh=3)

clean_payment_dataframes_2017_to_2020[2018] = df_2018
df_2018
# Out:
#           Country  ConvertedSalary YearsCodingProf
# 1  United Kingdom          70841.0     18-20 years
# 4    South Africa          21426.0       0-2 years
# 5  United Kingdom          41671.0       3-5 years
# 6   United States         120000.0       0-2 years
# 8   United States         250000.0     21-23 years
#               Country  YearsCodePro  Monthly_Sal_EUR
# 1      United Kingdom            18      7079.967608
# 4        South Africa             0      2141.350150
# 5      United Kingdom             3      4164.669192
# 6       United States             0     11993.000000
# 17             Sweden             0      4787.605600
# ...               ...           ...              ...
# 87235      Kyrgyzstan             0      1559.090000
# 87239         Armenia             0       499.708333
# 87246        Pakistan             0       325.010300
# 87259       Argentina             0      2398.600000
# 87282   United States             6     14541.512500
#
# [43821 rows x 3 columns]

# %% [markdown]
# ### Covert 2019 - 2021 - these data frames have the same salary related columns

# %%
df_2019_2021 = [data_frames_dict[2019], data_frames_dict[2020], data_frames_dict[2021]]
years = [2019, 2020, 2021]

annual_rate = 1/12

for year in years:
    df = data_frames_dict[year]

    # convert the converted annual USD salary to monthly salary 
    df['Monthly_Sal_EUR'] = df.apply(
        lambda row : convert_currency(row['CompTotal'],'USD', annual_rate), axis = 1)
    
    # drop CompTotal column
    # Also drop outlier salaries 
    df = df.drop('CompTotal', axis=1)[(df.Monthly_Sal_EUR > min_montly_salary) & (df.Monthly_Sal_EUR < max_montly_salary)]
    df.YearsCodePro = df.YearsCodePro.apply(lambda experience:   min(map(lambda s: int(s), re.findall(r'\d+', experience)), default=np.nan))
    df= df.dropna(thresh=3)
    print(df.head())
    clean_payment_dataframes_2017_to_2020[year] = df
# Out:
#           Country  YearsCodePro  Monthly_Sal_EUR
# 2        Thailand             1      2298.658333
# 3   United States             1      6096.441667
# 5          Canada             3      3997.666667
# 8     New Zealand             4     13791.950000
# 12  United States             8      8994.750000
#            Country  YearsCodePro  Monthly_Sal_EUR
# 7    United States            13     11593.233333
# 9   United Kingdom             4      2498.541667
# 10  United Kingdom             2      3098.191667
# 11           Spain             7       109.935833
# 12     Netherlands            20       299.825000
#     Country  YearsCodePro  Monthly_Sal_EUR
# 9    Sweden             4      4197.550000
# 11    Spain             5      4297.491667
# 12  Germany             6      7145.829167
# 16   Turkey             2       899.475000
# 17   Canada             6      6096.441667

# %%
import codecs
import json
summary_df = None
i = 0
for year, df in clean_payment_dataframes_2017_to_2020.items():
    df = df.filter(items=['Country','Monthly_Sal_EUR', 'YearsCodePro'])
    
    
    # compute mean salary per country and reset the resulting df index
    
    
    print(len(df.Country.unique()))
    for country in df.Country.unique():
        print(country)
        df2 = df[df['Country'] == country]
        print(df2.head())
        df2.to_csv("processed_data/salaries/{}-{}-income_experience_per_country.csv".format(country,year))
# Out:
# 130
# United Kingdom
#             Country  Monthly_Sal_EUR  YearsCodePro
# 2    United Kingdom      8410.201042          20.0
# 14   United Kingdom      7393.583333          20.0
# 110  United Kingdom      2402.914583           1.0
# 113  United Kingdom      2218.075000           1.0
# 135  United Kingdom      2402.914583           2.0
# United States
#           Country  Monthly_Sal_EUR  YearsCodePro
# 17  United States     12992.416667          20.0
# 18  United States      8245.187500           3.0
# 25  United States     17489.791667          16.0
# 70  United States      6496.208333           1.0
# 72  United States     11993.000000          20.0
# Israel
#      Country  Monthly_Sal_EUR  YearsCodePro
# 22    Israel     10070.522100           5.0
# 162   Israel      2498.541667           3.0
# 282   Israel      7840.623633          11.0
# 308   Israel      5326.890833           3.0
# 1228  Israel      6496.208333           3.0
# Croatia
#       Country  Monthly_Sal_EUR  YearsCodePro
# 34    Croatia      1236.559140           1.0
# 90    Croatia      3857.748333           3.0
# 565   Croatia      2240.143369           5.0
# 1997  Croatia      6272.401434           5.0
# 4013  Croatia      3136.200717           4.0
# Argentina
#         Country  Monthly_Sal_EUR  YearsCodePro
# 36    Argentina      2818.355000           9.0
# 1831  Argentina      2998.250000           7.0
# 2204  Argentina      2998.250000           2.0
# 2304  Argentina      1499.125000           1.0
# 4452  Argentina      2498.541667           8.0
# Germany
#      Country  Monthly_Sal_EUR  YearsCodePro
# 37   Germany      9856.630824           7.0
# 54   Germany      5376.344086           4.0
# 95   Germany      4480.286738           4.0
# 102  Germany      6989.247312          17.0
# 191  Germany       896.057348           1.0
# Brazil
#     Country  Monthly_Sal_EUR  YearsCodePro
# 52   Brazil      5189.337030           1.0
# 104  Brazil      5799.084395          12.0
# 399  Brazil     10754.665605           2.0
# 412  Brazil      5061.019108           9.0
# 437  Brazil     12441.671975          11.0
# Italy
#      Country  Monthly_Sal_EUR  YearsCodePro
# 57     Italy      3584.229391           4.0
# 273    Italy      3136.200717           8.0
# 691    Italy      3584.229391          13.0
# 780    Italy      3655.913978          10.0
# 1851   Italy      3046.594982          20.0
# Netherlands
#           Country  Monthly_Sal_EUR  YearsCodePro
# 12875  Bangladesh       699.591667           2.0
# 13402  Bangladesh       499.708333           1.0
# 14235  Bangladesh       303.322958           1.0
# 21026  Bangladesh       649.620833           2.0
# 21649  Bangladesh      1499.125000           9.0
# Cyprus
#       Country  Monthly_Sal_EUR  YearsCodePro
# 13080  Cyprus      4032.258065           7.0
# 18472  Cyprus      1281.362007           1.0
# 22590  Cyprus      2688.172043           7.0
# 49625  Cyprus      4435.483871          17.0
# 51378  Cyprus      8960.573477           5.0
# Nicaragua
#          Country  Monthly_Sal_EUR  YearsCodePro
# 13240  Nicaragua      6496.208333           7.0
# Jordan
#       Country  Monthly_Sal_EUR  YearsCodePro
# 13273  Jordan      1349.212500           7.0
# 13813  Jordan       149.912500           5.0
# 21491  Jordan      7195.800000          15.0
# 26365  Jordan      1399.183333           3.0
# 33620  Jordan      3398.016667           5.0
# Honduras
#         Country  Monthly_Sal_EUR  YearsCodePro
# 14184  Honduras      1569.084167           8.0
# 27243  Honduras      1199.300000           4.0
# Tunisia
#        Country  Monthly_Sal_EUR  YearsCodePro
# 15280  Tunisia      1433.691756           4.0
# 16928  Tunisia        43.458781           2.0
# 28582  Tunisia       599.650000           3.0
# 38022  Tunisia       599.650000           3.0
# Mongolia
#         Country  Monthly_Sal_EUR  YearsCodePro
# 15975  Mongolia           599.65           4.0
# Japan
#       Country  Monthly_Sal_EUR  YearsCodePro
# 16016   Japan      5511.283208           7.0
# 23291   Japan     19544.572802           4.0
# 35441   Japan        76.223834           5.0
# 40569   Japan      3518.023104           1.0
# 46081   Japan      4690.697472           1.0
# Chile
#       Country  Monthly_Sal_EUR  YearsCodePro
# 16528   Chile      4497.375000           9.0
# 17523   Chile       121.728950           1.0
# 24039   Chile      1998.833333           5.0
# 34089   Chile       999.416667           3.0
# 43500   Chile      2198.716667           1.0
# Kyrgyzstan
#           Country  Monthly_Sal_EUR  YearsCodePro
# 16706  Kyrgyzstan      1699.008333          14.0
# Puerto Rico
#            Country  Monthly_Sal_EUR  YearsCodePro
# 17318  Puerto Rico     17989.500000           2.0
# 17924  Puerto Rico      4797.200000           2.0
# 23016  Puerto Rico      1998.833333           1.0
# 48118  Puerto Rico      3997.666667           1.0
# New Caledonia (French)
#                       Country  Monthly_Sal_EUR  YearsCodePro
# 17431  New Caledonia (French)      2598.566308           4.0
# 31728  New Caledonia (French)      2508.960573           3.0
# 51220  New Caledonia (French)      4032.258065          10.0
# Zaire
#       Country  Monthly_Sal_EUR  YearsCodePro
# 17684   Zaire           479.72           2.0
# Venezuela
#          Country  Monthly_Sal_EUR  YearsCodePro
# 18020  Venezuela     15990.666667           7.0
# 23205  Venezuela      2398.600000           5.0
# 34627  Venezuela       399.766667           3.0
# 41463  Venezuela        49.970833           4.0
# 43227  Venezuela        39.976667           7.0
# Ghana
#       Country  Monthly_Sal_EUR  YearsCodePro
# 18841   Ghana        57.366517           5.0
# 42808   Ghana      9394.516667           7.0
# Bolivia
#        Country  Monthly_Sal_EUR  YearsCodePro
# 19754  Bolivia        99.941667           2.0
# 31406  Bolivia       927.658550           2.0
# 41846  Bolivia      2998.250000           1.0
# 48361  Bolivia      1199.300000           3.0
# Taiwan
#       Country  Monthly_Sal_EUR  YearsCodePro
# 19798  Taiwan       109.935833           1.0
# 45853  Taiwan      3997.666667           2.0
# Malta
#       Country  Monthly_Sal_EUR  YearsCodePro
# 21935   Malta      2164.247312           5.0
# 21974   Malta      2150.537634           5.0
# 25817   Malta      1926.523297           4.0
# 26718   Malta      2419.354839           4.0
# 27216   Malta      4121.863799          16.0
# Bahrain
#        Country  Monthly_Sal_EUR  YearsCodePro
# 22782  Bahrain         7495.625          11.0
# Seychelles
#           Country  Monthly_Sal_EUR  YearsCodePro
# 23594  Seychelles      1399.183333           3.0
# Guinea
#       Country  Monthly_Sal_EUR  YearsCodePro
# 24008  Guinea      6995.916667           7.0
# Philippines
#            Country  Monthly_Sal_EUR  YearsCodePro
# 26466  Philippines      2998.250000          14.0
# 42644  Philippines       169.900833           7.0
# Mozambique
#           Country  Monthly_Sal_EUR  YearsCodePro
# 26727  Mozambique          1798.95           4.0
# Reunion (French)
#                 Country  Monthly_Sal_EUR  YearsCodePro
# 29336  Reunion (French)      4480.286738           1.0
# Montenegro
#           Country  Monthly_Sal_EUR  YearsCodePro
# 29608  Montenegro       896.057348           4.0
# 30948  Montenegro       860.215054           3.0
# Guam
#       Country  Monthly_Sal_EUR  YearsCodePro
# 29826    Guam      7875.403333           6.0
# Kazakhstan
#           Country  Monthly_Sal_EUR  YearsCodePro
# 32195  Kazakhstan        99.941667           2.0
# Barbados
#         Country  Monthly_Sal_EUR  YearsCodePro
# 32625  Barbados          2998.25          14.0
# Madagascar
#           Country  Monthly_Sal_EUR  YearsCodePro
# 34321  Madagascar      2867.383513           3.0
# Syria
#       Country  Monthly_Sal_EUR  YearsCodePro
# 35603   Syria       249.854167           4.0
# 39504   Syria       599.650000           2.0
# Morocco
#        Country  Monthly_Sal_EUR  YearsCodePro
# 37241  Morocco       896.057348           5.0
# 47612  Morocco      1199.300000           2.0
# Guatemala
#          Country  Monthly_Sal_EUR  YearsCodePro
# 37276  Guatemala          4197.55           7.0
# 40383  Guatemala          5396.85           5.0
# Cambodia
#         Country  Monthly_Sal_EUR  YearsCodePro
# 37879  Cambodia        49.970833           2.0
# Uzbekistan
#           Country  Monthly_Sal_EUR  YearsCodePro
# 38043  Uzbekistan           5996.5           7.0
# Martinique (French)
#                    Country  Monthly_Sal_EUR  YearsCodePro
# 38984  Martinique (French)       2087.81362           2.0
# Yemen
#       Country  Monthly_Sal_EUR  YearsCodePro
# 39630   Yemen        99.941667           3.0
# Virgin Islands (USA)
#                     Country  Monthly_Sal_EUR  YearsCodePro
# 41710  Virgin Islands (USA)     17489.791667           7.0
# Suriname
#         Country  Monthly_Sal_EUR  YearsCodePro
# 41917  Suriname           1199.3           5.0
# Cayman Islands
#               Country  Monthly_Sal_EUR  YearsCodePro
# 41942  Cayman Islands      5728.356508           4.0
# Botswana
#         Country  Monthly_Sal_EUR  YearsCodePro
# 43084  Botswana          1918.88           1.0
# Iceland
#        Country  Monthly_Sal_EUR  YearsCodePro
# 3332  Slovenia      4036.843800             3
# 4647  Slovenia      1409.177500             3
# 5410  Slovenia      3057.915175             3
# El Salvador
#            Country  Monthly_Sal_EUR  YearsCodePro
# 1330   El Salvador        1319.2300             3
# ...
# 39792  Iceland       699.591667            22
# 58510  Iceland       699.591667             5
# El Salvador
#            Country  Monthly_Sal_EUR  YearsCodePro
# 4584   El Salvador        29.982500             1
# 9050   El Salvador       229.865833             6
# 17044  El Salvador       199.883333             8
# 28621  El Salvador        89.947500             1
# 29537  El Salvador      2798.366667             6
# Iraq
#       Country  Monthly_Sal_EUR  YearsCodePro
# 4625     Iraq      1998.833333             1
# 13170    Iraq      4997.083333             2
# 22088    Iraq       139.918333             3
# 24066    Iraq      5996.500000             7
# 37713    Iraq        99.941667             2
# Kosovo
#       Country  Monthly_Sal_EUR  YearsCodePro
# 4773   Kosovo        23.986000             4
# 15792  Kosovo      4997.083333            10
# 20524  Kosovo      7795.450000             9
# 23925  Kosovo       186.491150             3
# 29033  Kosovo       148.913083             3
# Andorra
#        Country  Monthly_Sal_EUR  YearsCodePro
# 5802   Andorra     10393.933333             8
# 34843  Andorra      6995.916667             5
# 49793  Andorra       169.900833             2
# New Zealand
#           Country  Monthly_Sal_EUR  YearsCodePro
# 5914  New Zealand      5496.791667             2
# 5983  New Zealand       699.591667            30
# 6492  New Zealand      7495.625000             4
# 6866  New Zealand     13991.833333            22
# 7254  New Zealand     14991.250000             4
# Dominica
#        Country  Monthly_Sal_EUR  YearsCodePro
# 6164  Dominica      4997.083333             4
# Chile
#       Country  Monthly_Sal_EUR  YearsCodePro
# 6173    Chile       589.655833             7
# 18925   Chile       199.883333             6
# 20321   Chile      9494.458333            20
# 20436   Chile        99.941667             9
# 20596   Chile     17189.966667            31
# Nomadic
#        Country  Monthly_Sal_EUR  YearsCodePro
# 6210   Nomadic      7295.741667            12
# 7110   Nomadic     17989.500000            11
# 13488  Nomadic      8395.100000             6
# 23644  Nomadic      7995.333333            11
# 26731  Nomadic      8495.041667             4
# Nicaragua
#          Country  Monthly_Sal_EUR  YearsCodePro
# 6721   Nicaragua       999.416667             1
# 9689   Nicaragua        43.974333             9
# 18766  Nicaragua        99.941667             4
# 28144  Nicaragua        99.941667             5
# 44083  Nicaragua      6716.080000             3
# Trinidad and Tobago
#                    Country  Monthly_Sal_EUR  YearsCodePro
# 6870   Trinidad and Tobago      1299.241667            17
# 9923   Trinidad and Tobago       749.562500             6
# 19902  Trinidad and Tobago        99.941667            32
# 20723  Trinidad and Tobago      1599.066667             2
# 26845  Trinidad and Tobago       499.708333             3
# Barbados
#         Country  Monthly_Sal_EUR  YearsCodePro
# 7611   Barbados       399.766667             3
# 39410  Barbados      3098.191667             3
# 44183  Barbados       199.883333             5
# 50995  Barbados      2038.810000            10
# 63869  Barbados      5996.500000            10
# Mauritius
#          Country  Monthly_Sal_EUR  YearsCodePro
# 8050   Mauritius      6995.916667            15
# 14693  Mauritius      5596.733333             7
# 23451  Mauritius      3997.666667             3
# 24743  Mauritius      2398.600000             1
# 37079  Mauritius      3797.783333             4
# Yemen
#       Country  Monthly_Sal_EUR  YearsCodePro
# 8135    Yemen         9.994167             3
# 17594   Yemen      9994.166667             1
# 40136   Yemen        14.991250             1
# 78997   Yemen        29.982500             4
# 79190   Yemen      8994.750000             1
# Kuwait
#       Country  Monthly_Sal_EUR  YearsCodePro
# 8289   Kuwait        44.973750            11
# 9509   Kuwait       482.718250            30
# 20047  Kuwait       339.801667            10
# 20649  Kuwait       159.906667             1
# 24109  Kuwait        64.962083             2
# Gambia
#       Country  Monthly_Sal_EUR  YearsCodePro
# 8692   Gambia      2998.250000            14
# 65677  Gambia      4997.083333             2
# Ghana
#       Country  Monthly_Sal_EUR  YearsCodePro
# 8875    Ghana       399.766667             6
# 9376    Ghana       310.818583             4
# 13365   Ghana        12.492708             2
# 15995   Ghana       499.708333             4
# 18641   Ghana        17.289908             1
# Congo, Republic of the...
#                          Country  Monthly_Sal_EUR  YearsCodePro
# 8985   Congo, Republic of the...        31.981333             4
# 27889  Congo, Republic of the...      1798.950000            12
# 36676  Congo, Republic of the...      4997.083333            16
# 48135  Congo, Republic of the...     12492.708333             3
# 69284  Congo, Republic of the...        99.941667             2
# Mauritania
#           Country  Monthly_Sal_EUR  YearsCodePro
# 9596   Mauritania       999.416667             1
# 69474  Mauritania      5996.500000             6
# Hong Kong (S.A.R.)
#                   Country  Monthly_Sal_EUR  YearsCodePro
# 9694   Hong Kong (S.A.R.)      5996.500000             5
# 10116  Hong Kong (S.A.R.)      1499.125000             1
# 10407  Hong Kong (S.A.R.)       281.835500             1
# 11015  Hong Kong (S.A.R.)      2198.716667             3
# 12565  Hong Kong (S.A.R.)      3198.133333             6
# South Korea
#            Country  Monthly_Sal_EUR  YearsCodePro
# 10525  South Korea       559.673333             5
# 18188  South Korea      7995.333333             3
# 31662  South Korea      1499.125000            25
# 37761  South Korea       759.556667            14
# 44346  South Korea      4997.083333             6
# Cambodia
#         Country  Monthly_Sal_EUR  YearsCodePro
# 10772  Cambodia        39.976667             1
# 20070  Cambodia       149.912500             9
# 39210  Cambodia     19988.333333             1
# 44472  Cambodia        39.976667             3
# 54127  Cambodia        44.973750             2
# Kyrgyzstan
#           Country  Monthly_Sal_EUR  YearsCodePro
# 10792  Kyrgyzstan      8495.041667             2
# 11629  Kyrgyzstan      7995.333333             7
# 14315  Kyrgyzstan       249.854167             2
# 15531  Kyrgyzstan     12992.416667             8
# 21079  Kyrgyzstan      3497.958333             1
# Kazakhstan
#           Country  Monthly_Sal_EUR  YearsCodePro
# 11293  Kazakhstan       399.766667             7
# 15252  Kazakhstan     19988.333333             3
# 25010  Kazakhstan     12492.708333             3
# 27338  Kazakhstan      7795.450000             1
# 37598  Kazakhstan     19988.333333             2
# Afghanistan
#            Country  Monthly_Sal_EUR  YearsCodePro
# 11377  Afghanistan      6296.325000             5
# 14882  Afghanistan       649.620833             4
# 17120  Afghanistan      1998.833333             1
# 17486  Afghanistan      3497.958333             3
# 31086  Afghanistan     15401.010833            13
# Swaziland
#          Country  Monthly_Sal_EUR  YearsCodePro
# 12033  Swaziland      1499.125000             3
# 22974  Swaziland       649.620833             3
# 37133  Swaziland       499.708333             2
# 43801  Swaziland      5696.675000            19
# 74783  Swaziland       209.877500             4
# Saint Kitts and Nevis
#                      Country  Monthly_Sal_EUR  YearsCodePro
# 13268  Saint Kitts and Nevis      5496.791667             1
# Monaco
#       Country  Monthly_Sal_EUR  YearsCodePro
# 14564  Monaco       201.082633             4
# Myanmar
#        Country  Monthly_Sal_EUR  YearsCodePro
# 15033  Myanmar        79.953333             3
# 22405  Myanmar       429.749167             7
# 53724  Myanmar        34.979583             3
# 56781  Myanmar     19988.333333             1
# 73144  Myanmar        59.965000             5
# Turkmenistan
#             Country  Monthly_Sal_EUR  YearsCodePro
# 15267  Turkmenistan       399.766667            12
# 39712  Turkmenistan       399.766667             1
# 61829  Turkmenistan      4997.083333             1
# 75763  Turkmenistan       499.708333             1
# Libyan Arab Jamahiriya
#                       Country  Monthly_Sal_EUR  YearsCodePro
# 16049  Libyan Arab Jamahiriya      2998.250000             3
# 78947  Libyan Arab Jamahiriya       399.766667             1
# Sudan
#       Country  Monthly_Sal_EUR  YearsCodePro
# 16631   Sudan         9.994167             3
# 28118   Sudan       199.883333             5
# 29793   Sudan         9.994167             2
# 48644   Sudan        39.976667             1
# 49570   Sudan      9994.166667             3
# Montenegro
#           Country  Monthly_Sal_EUR  YearsCodePro
# 16867  Montenegro       299.825000             4
# 18324  Montenegro       119.930000            23
# 25735  Montenegro       159.906667             6
# 26948  Montenegro       179.895000             5
# 27773  Montenegro       119.930000            14
# Isle of Man
#            Country  Monthly_Sal_EUR  YearsCodePro
# 18519  Isle of Man      3098.191667             4
# 23729  Isle of Man      6995.916667            11
# 65240  Isle of Man     13751.973333            22
# Qatar
#       Country  Monthly_Sal_EUR  YearsCodePro
# 19028   Qatar      3398.016667             4
# 39807   Qatar      2398.600000             1
# 42457   Qatar       949.445833            10
# 48381   Qatar      2698.425000            11
# 58332   Qatar      2998.250000             9
# Haiti
#       Country  Monthly_Sal_EUR  YearsCodePro
# 19528   Haiti       299.825000            11
# 33473   Haiti      5496.791667            10
# Belize
#       Country  Monthly_Sal_EUR  YearsCodePro
# 19668  Belize       299.825000             6
# 66772  Belize      4557.340000            11
# 79999  Belize      4597.316667             1
# Benin
#       Country  Monthly_Sal_EUR  YearsCodePro
# 19974   Benin        39.976667             2
# 74063   Benin     14991.250000             1
# 83174   Benin        21.987167             2
# 83435   Benin     19988.333333             2
# Bhutan
#       Country  Monthly_Sal_EUR  YearsCodePro
# 20639  Bhutan       199.883333            11
# 59424  Bhutan      2998.250000             2
# Palestine
#          Country  Monthly_Sal_EUR  YearsCodePro
# 21262  Palestine       269.842500            12
# 28176  Palestine       539.685000             4
# 32230  Palestine       149.912500            30
# 33543  Palestine       469.725833             1
# 39570  Palestine      2298.658333             3
# Republic of Korea
#                  Country  Monthly_Sal_EUR  YearsCodePro
# 22032  Republic of Korea       379.778333             1
# Indonesia
#          Country  Monthly_Sal_EUR  YearsCodePro
# 22053  Indonesia       449.737500             3
# 22371  Indonesia       199.883333             1
# 37522  Indonesia       249.854167            10
# 41431  Indonesia       349.795833             5
# 63015  Indonesia      1699.008333             5
# Tajikistan
#           Country  Monthly_Sal_EUR  YearsCodePro
# 22592  Tajikistan      1499.125000             3
# 48304  Tajikistan       699.591667             2
# 73191  Tajikistan       199.883333             1
# United Republic of Tanzania
#                            Country  Monthly_Sal_EUR  YearsCodePro
# 22676  United Republic of Tanzania      5996.500000             3
# 45768  United Republic of Tanzania      8495.041667            13
# 50520  United Republic of Tanzania      1998.833333             4
# 79228  United Republic of Tanzania      6995.916667             5
# Cape Verde
#           Country  Monthly_Sal_EUR  YearsCodePro
# 26106  Cape Verde        99.941667            11
# 62121  Cape Verde      8095.275000             7
# Oman
#       Country  Monthly_Sal_EUR  YearsCodePro
# 26234    Oman       599.650000            10
# 27672    Oman        99.941667            22
# 30202    Oman        79.953333             8
# 64407    Oman       249.854167             8
# Angola
#       Country  Monthly_Sal_EUR  YearsCodePro
# 26833  Angola      8195.216667             4
# 28920  Angola       799.533333             3
# 37306  Angola      2998.250000             4
# 53851  Angola         9.994167             2
# 72215  Angola     12992.416667             6
# Uganda
#       Country  Monthly_Sal_EUR  YearsCodePro
# 26881  Uganda        29.982500             1
# 29425  Uganda       399.766667             8
# 33799  Uganda       423.252958            15
# 42184  Uganda       129.924167             4
# 46839  Uganda       299.825000             5
# Lao People's Democratic Republic
#                                 Country  Monthly_Sal_EUR  YearsCodePro
# 27438  Lao People's Democratic Republic       499.708333             7
# Zimbabwe
#         Country  Monthly_Sal_EUR  YearsCodePro
# 27472  Zimbabwe       299.825000             9
# 29070  Zimbabwe        59.965000             2
# 29692  Zimbabwe        99.941667             3
# 31652  Zimbabwe        29.982500             3
# 39746  Zimbabwe        19.488625             2
# CÃ´te d'Ivoire
#               Country  Monthly_Sal_EUR  YearsCodePro
# 27936  CÃ´te d'Ivoire     14991.250000             4
# 28584  CÃ´te d'Ivoire        44.973750             9
# 71251  CÃ´te d'Ivoire      9994.166667             3
# 83176  CÃ´te d'Ivoire     14991.250000             2
# Senegal
#        Country  Monthly_Sal_EUR  YearsCodePro
# 28062  Senegal         0.099942            10
# 75033  Senegal       479.720000             6
# Namibia
#        Country  Monthly_Sal_EUR  YearsCodePro
# 28164  Namibia      2698.425000             4
# 31711  Namibia      3997.666667            10
# 32968  Namibia      3753.609117             3
# 41714  Namibia      7995.333333             6
# 43230  Namibia       319.813333            17
# Lesotho
#        Country  Monthly_Sal_EUR  YearsCodePro
# 28580  Lesotho         449.7375             6
# 31311  Lesotho        1798.9500             8
# 58149  Lesotho         599.6500             4
# Jamaica
#        Country  Monthly_Sal_EUR  YearsCodePro
# 30445  Jamaica     14991.250000             1
# 35890  Jamaica      9994.166667             5
# 36198  Jamaica     12992.416667             2
# 40964  Jamaica        39.976667             1
# Liberia
#        Country  Monthly_Sal_EUR  YearsCodePro
# 33043  Liberia        13.592067             5
# Suriname
#         Country  Monthly_Sal_EUR  YearsCodePro
# 35225  Suriname     19988.333333             5
# 56645  Suriname       224.868750             1
# Niger
#       Country  Monthly_Sal_EUR  YearsCodePro
# 36136   Niger      9094.691667            12
# Maldives
#         Country  Monthly_Sal_EUR  YearsCodePro
# 36627  Maldives      3997.666667             2
# 40606  Maldives      1938.868333             8
# 44032  Maldives      3997.666667             6
# 48043  Maldives      1798.950000             4
# 53378  Maldives       999.416667             9
# Madagascar
#           Country  Monthly_Sal_EUR  YearsCodePro
# 36801  Madagascar        62.963250             3
# 54411  Madagascar     19988.333333             1
# 55610  Madagascar      9994.166667             2
# 62506  Madagascar      9994.166667             2
# Saint Lucia
#            Country  Monthly_Sal_EUR  YearsCodePro
# 40207  Saint Lucia       219.871667             2
# Rwanda
#       Country  Monthly_Sal_EUR  YearsCodePro
# 42961  Rwanda        79.953333             4
# 44220  Rwanda       199.883333             9
# 45279  Rwanda     12492.708333             1
# 68796  Rwanda        34.979583             3
# 69430  Rwanda        49.970833             3
# Guyana
#       Country  Monthly_Sal_EUR  YearsCodePro
# 47622  Guyana      7995.333333             1
# San Marino
#           Country  Monthly_Sal_EUR  YearsCodePro
# 49433  San Marino      4597.316667            30
# Mozambique
#           Country  Monthly_Sal_EUR  YearsCodePro
# 50190  Mozambique       684.600417             4
# 54214  Mozambique      5896.558333             3
# 82248  Mozambique      3497.958333             1
# Malawi
#       Country  Monthly_Sal_EUR  YearsCodePro
# 50252  Malawi     12747.859408             9
# Togo
#       Country  Monthly_Sal_EUR  YearsCodePro
# 52551    Togo      9994.166667             2
# Saint Vincent and the Grenadines
#                                 Country  Monthly_Sal_EUR  YearsCodePro
# 54468  Saint Vincent and the Grenadines           599.65             3
# Fiji
#       Country  Monthly_Sal_EUR  YearsCodePro
# 67160    Fiji        69.959167             3
# North Korea
#            Country  Monthly_Sal_EUR  YearsCodePro
# 77133  North Korea      1998.833333             6

# %% [markdown]
# ### Compute a summary pdf - average of montly salaries per country

# %%
import codecs
import json
summary_df = None
i = 0
for year, df in clean_payment_dataframes_2017_to_2020.items():
    df = df.filter(items=['Country','Monthly_Sal_EUR'])
    
    df2 = df.copy(deep=True)
    
    # compute mean salary per country and reset the resulting df index
    df =  df.groupby('Country').mean().round(2).reset_index()
    
    # add column names 
    df.columns = ['Country', year]
    
    # merge the resulting dataframes into a single df columns = years, rows = countries
    if i > 0:
        summary_df = pd.DataFrame.merge(summary_df,df,on='Country')
        i+=1 
    else:
        summary_df =  df
        i+=1
        
    df2.columns = ['Country', 'respondentsCount']

    df2 = df2.groupby(by=['Country'] , as_index=False).count()
    
    print(df2.shape)
        
    print(df2.head())
    
    json_dict2 = {}
    for index, row in df2.iterrows():
        json_dict2[row["Country"]] = row["respondentsCount"]
  

    
  
    with codecs.open("processed_data/salaries/{}-income_respondents_count_per_country.json".format(year), "w", encoding='utf-8') as outfile:
        json.dump(json_dict2, outfile, indent = 4, ensure_ascii=False)

# Transpose the summary_df, now  columns = countries and rows = years 
summary_df = summary_df.T

# Pick all the countries -> first row of the transposed matrix
column_names = summary_df.iloc[0]
column_names = list(column_names) 

# drop the first row containing countries' names, instead make the countries the column names 
summary_df = summary_df.drop('Country')
summary_df.columns = column_names

# You can finally do some simple plots 
summary_df.plot( xticks = [2017, 2018, 2019, 2020, 2021], title= "A dirty plot of the world :P ")
summary_df[['Uzbekistan','France'] ].plot( xticks = [2017, 2018, 2019, 2020, 2021], title = "Uzbekistan vs. France ")
summary_df.to_json(path_or_buf = 'processed_data/salaries/average_montly_salary_in_Euros_per_country_per_year.json', index=True, indent = 4)
# Out:
# (130, 2)
#        Country  respondentsCount
# 0  Afghanistan                 2
# 1      Albania                 8
# 2    Argentina                20
# 3      Armenia                 6
# 4    Australia               239
# (156, 2)
#        Country  respondentsCount
# 0  Afghanistan                 4
# 1      Albania                33
# 2      Algeria                24
# 3      Andorra                 2
# 4    Argentina               281
# (153, 2)
#        Country  respondentsCount
# 0  Afghanistan                10
# 1      Albania                45
# 2      Algeria                37
# 3      Andorra                 2
# 4    Argentina               363
# (155, 2)
#        Country  respondentsCount
# 0  Afghanistan                19
# 1      Albania                16
# 2      Algeria                16
# 3      Andorra                 2
# 4       Angola                 2
# (167, 2)
#        Country  respondentsCount
# 0  Afghanistan                 8
# 1      Albania                26
# 2      Algeria                12
# 3      Andorra                 3
# 4       Angola                 6

# %%
summary_df
# Out:
#      Afghanistan  Albania Argentina  Armenia Australia  Austria  Bahrain  \
# 2017     4919.02   4607.0   3121.05  1907.22    8936.4  3812.17  7495.62
# 2018      875.86  1744.91   2840.88  2425.39   8282.28  5553.44  2940.08
# 2019     4397.47  5401.56   5263.91  7972.01   9545.27  3122.71    75.15
# 2020      5639.8  6991.55   7322.78  8897.31    9890.0  3318.58   536.59
# 2021     5071.24  6578.08   7841.24  7902.05  10038.87  3704.04   759.82
#
#      Bangladesh Barbados  Belarus  ...   Turkey   Uganda  Ukraine  \
# 2017     3037.5  2998.25  2399.74  ...  2607.62  11993.0  2578.77
# 2018     1539.6  1827.13  2620.18  ...  2867.95  1860.29  2483.34
# 2019    6088.48    349.8   487.12  ...   1691.7   6167.4  4018.83
# 2020    5517.11   417.66   481.51  ...  1803.29  1223.29  4297.24
# 2021    5467.95   2345.5   850.18  ...  1757.87   228.94  4494.87
#
#      United Arab Emirates United Kingdom United States  Uruguay Uzbekistan  \
# 2017              3845.16        3993.19       9775.93  4795.25     5996.5
# 2018              5378.03        6628.02       9876.95  3985.47    1464.81
# 2019              1837.64         4874.6      10068.28  5412.18    1994.74
# 2020              2043.48         5081.6      10490.66  7838.29     214.37
# 2021              1764.93         5709.5      11122.11  5909.05     552.71
#
#         Yemen Zimbabwe
# 2017    99.94    69.96
# 2018   869.29  2316.49
# 2019  7620.55   783.71
# 2020   299.82   473.45
# 2021  3808.78   113.52
#
# [5 rows x 101 columns]

# %%
df = clean_payment_dataframes_2017_to_2020[2017]
df[df.Monthly_Sal_EUR > max_montly_salary]
# Out:
# Empty DataFrame
# Columns: [Country, YearsCodePro, Monthly_Sal_EUR]
# Index: []

# %%
summary_df = None
i = 0
for year, df in clean_payment_dataframes_2017_to_2020.items():
    df = df.filter(items=['Country', 'YearsCodePro'] )
    print(df.head())
    # compute mean salary per country and reset the resulting df index
    df =  df.groupby('Country').mean().astype(int).reset_index()
    print(df.head())

    # add column names 
    df.columns = ['Country', year]
    
    # merge the resulting dataframes into a single df columns = years, rows = countries
    if i > 0:
        summary_df = pd.DataFrame.merge(summary_df,df,on='Country')
        i+=1 
    else:
        summary_df =  df
        i+=1

# Transpose the summary_df, now  columns = countries and rows = years 
summary_df = summary_df.T

# Pick all the countries -> first row of the transposed matrix
column_names = summary_df.iloc[0]
column_names = list(column_names) 

# drop the first row containing countries' names, instead make the countries the column names 
summary_df = summary_df.drop('Country')
summary_df.columns = column_names

# You can finally do some simple plots 
summary_df.plot( xticks = [2017, 2018, 2019, 2020, 2021], title= "A dirty plot of the world :P ")
summary_df[['Uzbekistan','France'] ].plot( xticks = [2017, 2018, 2019, 2020, 2021], title = "Uzbekistan vs. France ")

summary_df.to_json(path_or_buf = 'processed_data/experience/average_experience_per_country_per_year.json', index=True, indent=4)
# Out:
#            Country  YearsCodePro
# 2   United Kingdom          20.0
# 14  United Kingdom          20.0
# 17   United States          20.0
# 18   United States           3.0
# 22          Israel           5.0
#        Country  YearsCodePro
# 0  Afghanistan             9
# 1      Albania             2
# 2    Argentina             8
# 3      Armenia             4
# 4    Australia             8
#            Country  YearsCodePro
# 1   United Kingdom            18
# 4     South Africa             0
# 5   United Kingdom             3
# 6    United States             0
# 17          Sweden             0
#        Country  YearsCodePro
# 0  Afghanistan             1
# 1      Albania             2
# 2      Algeria             3
# 3      Andorra            22
# 4    Argentina             6
#           Country  YearsCodePro
# 2        Thailand             1
# 3   United States             1
# 5          Canada             3
# 8     New Zealand             4
# 12  United States             8
#        Country  YearsCodePro
# 0  Afghanistan             3
# 1      Albania             4
# 2      Algeria             5
# 3      Andorra            22
# 4    Argentina             7
#            Country  YearsCodePro
# 7    United States            13
# 9   United Kingdom             4
# 10  United Kingdom             2
# 11           Spain             7
# 12     Netherlands            20
#        Country  YearsCodePro
# 0  Afghanistan             6
# 1      Albania             5
# 2      Algeria             5
# 3      Andorra            27
# 4       Angola             2
#     Country  YearsCodePro
# 9    Sweden             4
# 11    Spain             5
# 12  Germany             6
# 16   Turkey             2
# 17   Canada             6
#        Country  YearsCodePro
# 0  Afghanistan            10
# 1      Albania             3
# 2      Algeria             3
# 3      Andorra             5
# 4       Angola             3

# %%
summary_df
# Out:
#      Afghanistan Albania Argentina Armenia Australia Austria Bahrain  \
# 2017           9       2         8       4         8       6      11
# 2018           1       2         6       4         8       6       7
# 2019           3       4         7       4        10       7       6
# 2020           6       5         9       4        11       8       9
# 2021          10       3         8       6        11       9      15
#
#      Bangladesh Barbados Belarus  ... Turkey Uganda Ukraine  \
# 2017          6       14       4  ...      6      5       6
# 2018          2        1       4  ...      5      3       3
# 2019          4        5       6  ...      6      2       6
# 2020          3        7       7  ...      6      2       7
# 2021          4        5       7  ...      6      5       7
#
#      United Arab Emirates United Kingdom United States Uruguay Uzbekistan  \
# 2017                    5              7             8       9          7
# 2018                    6              7             7       7          3
# 2019                    7              9             9       7          7
# 2020                    6              9             9       9          6
# 2021                    8             11            10       8          3
#
#      Yemen Zimbabwe
# 2017     3        1
# 2018     2        2
# 2019     4        4
# 2020    15        4
# 2021     2        3
#
# [5 rows x 101 columns]
