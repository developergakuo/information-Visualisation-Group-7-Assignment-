# %%
import pandas as pd
import numpy as np
import re #Regex lib
from forex_python.converter import CurrencyRates #currencies lib
from datetime import datetime
import matplotlib

# %% [markdown]
# ### Read in the dataframes and create a dict {(year, dataframe)}

# %%
# Create a list of filenames for the datasets

data_frames_dict = {}

data_frames_dict[2017] = pd.read_csv('datasets/2017.csv', encoding = "ISO-8859-1").filter(items=['Country', 'Currency',  'Salary', 'FormalEducation']).dropna(thresh=4) 
data_frames_dict[2018] = pd.read_csv('datasets/2018.csv', encoding = "ISO-8859-1").filter(items=['Country',  'ConvertedSalary', 'FormalEducation']).dropna(thresh=3) 
data_frames_dict[2019] = pd.read_csv('datasets/2019.csv', encoding = "ISO-8859-1").filter (items=['Country',  'CompTotal', 'EdLevel']).dropna(thresh=3) 
data_frames_dict[2020] = pd.read_csv('datasets/2020.csv', encoding = "ISO-8859-1").filter (items=['Country',  'CompTotal', 'EdLevel']).dropna(thresh=3) 
data_frames_dict[2021] = pd.read_csv('datasets/2021.csv', encoding = "ISO-8859-1").filter (items=['Country','CompTotal', 'EdLevel']).dropna(thresh=3) 


#preprocess 2021
def check_countryType(country, US_state, UK_country):
    
    if  isinstance(US_state, str):
        return 'United States'
    elif isinstance(UK_country, str) or country == 'United Kingdom of Great Britain and Northern Ireland':
        return 'United Kingdom'
    else:
        return country


df_2021 = pd.read_csv('datasets/2021.csv', encoding = "ISO-8859-1").filter (items=['Country', 'US_State', 'UK_Country',  'CompTotal', 'EdLevel'])
df_2021 = df_2021.dropna(subset = ['CompTotal', 'EdLevel'])
df_2021.Country =  df_2021.apply(lambda row : check_countryType(row['Country'],row['US_State'],  
                     row['UK_Country']), axis=1)
df_2021 = df_2021.drop(['US_State', 'UK_Country'], axis = 1).dropna(thresh=3)
data_frames_dict[2021]  = df_2021
# Out:
# /var/folders/h2/9wb_tlwj1bd2smbvq_25k5z4097jdb/T/ipykernel_29005/3430896613.py:6: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frames_dict[2018] = pd.read_csv('datasets/2018.csv', encoding = "ISO-8859-1").filter(items=['Country',  'ConvertedSalary', 'FormalEducation']).dropna(thresh=3)

# %%
ed_dict =  {'Secondary school': 'Secondary school',
 "Some college/university study without earning a bachelor's degree" : "college/university without bachelor's degree",
 "Bachelor's degree": "Bachelor's degree",
 'Doctoral degree': 'Doctoral degree',
 "Master's degree": "Master's degree",
 'Professional degree': "Professional degree",
 'Primary/elementary school': 'Primary/elementary school',
 'I prefer not to answer': 'I prefer not to answer',
 'I never completed any formal education': 'No formal education', 
 'Bachelorâ\x80\x99s degree (BA, BS, B.Eng., etc.)': "Bachelor's degree",
 'Associate degree': 'Associate degree',
 'Some college/university study without earning a degree': "college/university without bachelor's degree",
 'Masterâ\x80\x99s degree (MA, MS, M.Eng., MBA, etc.)': "Master's degree",
 'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)': 'Secondary school',
 'Professional degree (JD, MD, etc.)': "Professional degree",
 'I never completed any formal education': 'No formal education', 
 'Other doctoral degree (Ph.D, Ed.D., etc.)':  'Doctoral degree',
 'Associate degree (A.A., A.S., etc.)': 'Associate degree',
 'Something else': 'Something else', 
 'Masterâ\x80\x99s degree (M.A., M.S., M.Eng., MBA, etc.)': "Master's degree",
 'Bachelorâ\x80\x99s degree (B.A., B.S., B.Eng., etc.)' : "Bachelor's degree",
 'Other doctoral degree (Ph.D., Ed.D., etc.)' : 'Doctoral degree'
}



for year, df in data_frames_dict.items():
    print(year)
    if 'EdLevel'not in df:
        print("here")
        df.columns = df.columns.str.replace("FormalEducation","EdLevel")
    print(df.columns)
    df["EdLevel"] = df.EdLevel.apply(lambda x: ed_dict[x])
# Out:
# 2017
# here
# Index(['Country', 'Currency', 'Salary', 'EdLevel'], dtype='object')
# 2018
# here
# Index(['Country', 'ConvertedSalary', 'EdLevel'], dtype='object')
# 2019
# Index(['Country', 'CompTotal', 'EdLevel'], dtype='object')
# 2020
# Index(['Country', 'CompTotal', 'EdLevel'], dtype='object')
# 2021
# Index(['Country', 'CompTotal', 'EdLevel'], dtype='object')

# %% [markdown]
# # Section 1: Salary preprocessing

# %% [markdown]
# ### The following currencies were found in the datasets and could not be converted to their equivalent currency symbols

# %%
currency_dict = {'Australian dollars (A$)': 'AUD',
 'Bitcoin (btc)': 'btc',
 'Brazilian reais (R$)': 'BRL',
 'British pounds sterling (Â£)': 'GBP',
 'Canadian dollars (C$)': 'CAD',
 'Chinese yuan renminbi (Â¥)': 'CNY',
 'Euros (â\x82¬)': 'EUR',
 'Indian rupees (?)': 'INR',
 'Japanese yen (Â¥)': 'JPY',
 'Polish zloty (zl)': 'PLN',
 'Russian rubles (?)': 'RUB',
 'Singapore dollars (S$)': 'SGD',
 'South African rands (R)': 'ZAR',
 'Swiss francs': 'CHF',
 'U.S. dollars ($)': 'USD',
 'none\tCook Islands dollar': 'NZD'}

# %% [markdown]
# ### Compute currency symbols and add them to the 'currency_dict'

# %%
#helper function to covert currency to its symbol 
def add_currencies_to_dict(currency, currency_dict):
        currency_symbol = re.findall(r'[ˆA-Z]{3}', currency )

        if currency_symbol:
            # redundnat to add symbol to a dict {symbol -> symbol}but helps to treat all currencies the same
            currency_dict[currency] = currency_symbol[0]
        else:
            if currency not in currency_dict:
                print("WARN: there is no conversion available for this currency {}".format(currency))


# go through the  'CurrencySymbol' column if exists, otherwise 'Currency' 
# add all currencies that are not NaN to the 'currency_dict'
for year , df in data_frames_dict.items():
    
    # Check if Currecny column is present in df
    if 'CurrencySymbol' in df:
        print("{} year dataframe has a 'CurrencySymbol' column ".format(year))
        for currency_symbol in df.CurrencySymbol:
            #check for NaN
            if not pd.isna(currency_symbol):
                # redundnat to add symbol to a dict {symbol -> symbol}but helps to treat all currencies the same
                currency_dict[currency_symbol] = currency_symbol
    elif 'Currency' in df:
        print("{} year dataframe has a 'Currency' column ".format(year))
        for currency in df.Currency:
            #check for NaN
            if not pd.isna(currency):
                # add to dict {currency -> currency_symbol}
                add_currencies_to_dict(currency, currency_dict)
# Out:
# 2017 year dataframe has a 'Currency' column

# %% [markdown]
# ### Preporcess the salary related columns (currency, salary, salary type etc ) for datasets

# %% [markdown]
# #### Auxilliary/helper methods for currency conversions

# %%
def convert_currency(amount, currency, factor):
    return available_currencies_for_conversion[currency] * amount * factor


currency_converter = CurrencyRates()
date = datetime(2017, 12, 31, 18, 36, 28, 151012)

available_currencies_for_conversion = currency_converter.get_rates('EUR', date)

available_currencies_for_conversion['EUR']  = 1

# Take care of outlier salaries 
# max montly income in euros
max_montly_salary = 20000

# minimum mothly income in euros
min_montly_salary = 0

# %%
#Dictionary to hold processed payments/salary dataframes for yeas 2017 - 2021

clean_payment_dataframes_2017_to_2020 ={}

# %% [markdown]
# ### Process 2017 payments

# %%
df_2017 = data_frames_dict[2017]

# annual salary divide by 12
annual_rate = float (1/12)


# for each currency entry, replace it with its currency symbol
df_2017.Currency = df_2017.Currency.apply(lambda x: currency_dict[x])


# Filter out the currencies that we cannot convert
df_2017 = df_2017[df_2017.Currency.apply(lambda c:   c  in available_currencies_for_conversion)]
    
# Covert salary to a euros and divide it by 12  
df_2017['Monthly_Sal_EUR'] = df_2017.apply(lambda row : convert_currency(row['Salary'],
                     row['Currency'], annual_rate), axis = 1)

# drop Currency, Salary columns 
# drop c salaries less than min_salary and greater than max salary 
df_2017 = df_2017.drop(['Currency','Salary' ], axis=1)
df_2017 = df_2017[(df_2017.Monthly_Sal_EUR > min_montly_salary) & (df_2017.Monthly_Sal_EUR < max_montly_salary)]



#drop any NA 
df_2017= df_2017.dropna(thresh=3)

clean_payment_dataframes_2017_to_2020[2017] = df_2017
df_2017
# Out:
# /var/folders/h2/9wb_tlwj1bd2smbvq_25k5z4097jdb/T/ipykernel_29005/3558656570.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2017['Monthly_Sal_EUR'] = df_2017.apply(lambda row : convert_currency(row['Salary'],
#               Country              EdLevel  Monthly_Sal_EUR
# 2      United Kingdom    Bachelor's degree      8410.201042
# 14     United Kingdom  Professional degree      7393.583333
# 17      United States    Bachelor's degree     12992.416667
# 18      United States    Bachelor's degree      8245.187500
# 22             Israel    Bachelor's degree     10070.522100
# ...               ...                  ...              ...
# 51371     Netherlands    Bachelor's degree      6182.795699
# 51378          Cyprus     Secondary school      8960.573477
# 51382          France      Master's degree      2688.172043
# 51387   United States    Bachelor's degree      5796.616667
# 51390   United States    Bachelor's degree      3997.666667
#
# [10850 rows x 3 columns]

# %% [markdown]
# ### Process 2018 payments

# %%
df_2018 = data_frames_dict[2018]

print(df_2018.head())

# convert the converted annual USD salary to monthly salary 
df_2018['Monthly_Sal_EUR'] = df_2018.apply(
    lambda row : convert_currency(row['ConvertedSalary'],'USD', annual_rate), axis = 1)

# We are no longer interested in the ConvertedSalary
# Also drop outlier salaries 
df_2018 = df_2018.drop('ConvertedSalary', axis=1)[(df_2018.Monthly_Sal_EUR > min_montly_salary) & (df_2018.Monthly_Sal_EUR < max_montly_salary)]



# drop any NA at this point 
df_2018= df_2018.dropna(thresh=3)

clean_payment_dataframes_2017_to_2020[2018] = df_2018
df_2018
# Out:
#           Country  ConvertedSalary  \
# 1  United Kingdom          70841.0
# 4    South Africa          21426.0
# 5  United Kingdom          41671.0
# 6   United States         120000.0
# 8   United States         250000.0
#
#                                         EdLevel
# 1                             Bachelor's degree
# 4  college/university without bachelor's degree
# 5                             Bachelor's degree
# 6  college/university without bachelor's degree
# 8  college/university without bachelor's degree
#               Country                                       EdLevel  \
# 1      United Kingdom                             Bachelor's degree
# 4        South Africa  college/university without bachelor's degree
# 5      United Kingdom                             Bachelor's degree
# 6       United States  college/university without bachelor's degree
# 17             Sweden                               Master's degree
# ...               ...                                           ...
# 89911   United States                              Secondary school
# 89913          Mexico                           Professional degree
# 89932  United Kingdom                             Bachelor's degree
# 89938           India                             Bachelor's degree
# 89954         Germany                              Secondary school
#
#        Monthly_Sal_EUR
# 1          7079.967608
# 4          2141.350150
# 5          4164.669192
# 6         11993.000000
# 17         4787.605600
# ...                ...
# 89911       999.416667
# 89913      2577.295700
# 89932      9717.628075
# 89938       194.286600
# 89954      1027.800100
#
# [43750 rows x 3 columns]

# %% [markdown]
# ### Covert 2019 - 2021 - these data frames have the same salary related columns

# %%
df_2019_2021 = [data_frames_dict[2019], data_frames_dict[2020], data_frames_dict[2021]]
years = [2019, 2020, 2021]

annual_rate = 1/12

for year in years:
    df = data_frames_dict[year]

    # convert the converted annual USD salary to monthly salary 
    df['Monthly_Sal_EUR'] = df.apply(
        lambda row : convert_currency(row['CompTotal'],'USD', annual_rate), axis = 1)
    
    # drop CompTotal column
    # Also drop outlier salaries 
    df = df.drop('CompTotal', axis=1)[(df.Monthly_Sal_EUR > min_montly_salary) & (df.Monthly_Sal_EUR < max_montly_salary)]
    df= df.dropna(thresh=3)
    print(df.head())
    clean_payment_dataframes_2017_to_2020[year] = df
# Out:
#           Country                                       EdLevel  \
# 2        Thailand                             Bachelor's degree
# 3   United States                             Bachelor's degree
# 5          Canada                             Bachelor's degree
# 8     New Zealand  college/university without bachelor's degree
# 12  United States                               Master's degree
#
#     Monthly_Sal_EUR
# 2       2298.658333
# 3       6096.441667
# 5       3997.666667
# 8      13791.950000
# 12      8994.750000
#            Country                                       EdLevel  \
# 7    United States                             Bachelor's degree
# 9   United Kingdom                               Master's degree
# 10  United Kingdom                             Bachelor's degree
# 11           Spain  college/university without bachelor's degree
# 12     Netherlands                              Secondary school
#
#     Monthly_Sal_EUR
# 7      11593.233333
# 9       2498.541667
# 10      3098.191667
# 11       109.935833
# 12       299.825000
#      Country            EdLevel  Monthly_Sal_EUR
# 0   Slovakia   Secondary school       479.720000
# 9     Sweden    Master's degree      4197.550000
# 11     Spain  Bachelor's degree      4297.491667
# 12   Germany    Master's degree      7145.829167
# 16    Turkey  Bachelor's degree       899.475000

# %%
import codecs
import json
summary_df = None
i = 0
for year, df in clean_payment_dataframes_2017_to_2020.items():
    df = df.filter(items=['Country','Monthly_Sal_EUR', 'EdLevel'])
    
    
    # compute mean salary per country and reset the resulting df index
    
    
    for country in df.Country.unique():
        df2 = df[df['Country'] == country]
        print(df2.head())
        df2.to_csv("processed_data/salaries/{}-{}-income_education_per_country.csv".format(country,year))
# Out:
#             Country  Monthly_Sal_EUR              EdLevel
# 2    United Kingdom      8410.201042    Bachelor's degree
# 14   United Kingdom      7393.583333  Professional degree
# 110  United Kingdom      2402.914583    Bachelor's degree
# 113  United Kingdom      2218.075000    Bachelor's degree
# 135  United Kingdom      2402.914583    Bachelor's degree
#           Country  Monthly_Sal_EUR  \
# 17  United States     12992.416667
# 18  United States      8245.187500
# 25  United States     17489.791667
# 70  United States      6496.208333
# 72  United States     11993.000000
#
#                                          EdLevel
# 17                             Bachelor's degree
# 18                             Bachelor's degree
# 25                               Master's degree
# 70  college/university without bachelor's degree
# 72  college/university without bachelor's degree
#      Country  Monthly_Sal_EUR                                       EdLevel
# 22    Israel     10070.522100                             Bachelor's degree
# 162   Israel      2498.541667  college/university without bachelor's degree
# 282   Israel      7840.623633                           No formal education
# 308   Israel      5326.890833  college/university without bachelor's degree
# 1228  Israel      6496.208333                             Bachelor's degree
#       Country  Monthly_Sal_EUR            EdLevel
# 34    Croatia      1236.559140  Bachelor's degree
# 90    Croatia      3857.748333  Bachelor's degree
# 565   Croatia      2240.143369    Master's degree
# 1997  Croatia      6272.401434    Master's degree
# 4013  Croatia      3136.200717    Master's degree
#         Country  Monthly_Sal_EUR                                       EdLevel
# 36    Argentina      2818.355000  college/university without bachelor's degree
# 1831  Argentina      2998.250000                             Bachelor's degree
# 2204  Argentina      2998.250000                               Master's degree
# 2304  Argentina      1499.125000                              Secondary school
# 4452  Argentina      2498.541667                        I prefer not to answer
#      Country  Monthly_Sal_EUR                                       EdLevel
# 37   Germany      9856.630824  college/university without bachelor's degree
# 54   Germany      5376.344086                               Master's degree
# 95   Germany      4480.286738                             Bachelor's degree
# 102  Germany      6989.247312                               Master's degree
# 191  Germany       896.057348  college/university without bachelor's degree
#     Country  Monthly_Sal_EUR                                       EdLevel
# 52   Brazil      5189.337030                             Bachelor's degree
# 104  Brazil      5799.084395                             Bachelor's degree
# 399  Brazil     10754.665605                               Master's degree
# 412  Brazil      5061.019108  college/university without bachelor's degree
# 437  Brazil     12441.671975                             Bachelor's degree
#      Country  Monthly_Sal_EUR                                       EdLevel
# 57     Italy      3584.229391                               Master's degree
# 273    Italy      3136.200717                             Bachelor's degree
# 691    Italy      3584.229391  college/university without bachelor's degree
# 780    Italy      3655.913978                              Secondary school
# 1851   Italy      3046.594982  college/university without bachelor's degree
#          Country  Monthly_Sal_EUR  \
# 64   Netherlands      5824.372760
# 212  Netherlands      2688.172043
# 232  Netherlands      4838.709677
# 314  Netherlands      3951.612903
# 402  Netherlands      5591.397849
#
#                                           EdLevel
# 64                                Master's degree
# 212                             Bachelor's degree
# 232                             Bachelor's degree
# 314                              Secondary school
# 402  college/university without bachelor's degree
#     Country  Monthly_Sal_EUR                 EdLevel
# 65   Poland      6188.148148       Bachelor's degree
# 247   Greece       179.211470                               Master's degree
# 1347  Greece      2460.035842                               Master's degree
# 1818  Greece      1827.956989                             Bachelor's degree
# 3330  Greece      1630.824373                               Master's degree
# 3455  Greece      2867.383513  college/university without bachelor's degree
#           Country  Monthly_Sal_EUR  \
# 264    Costa Rica      5896.558333
# 20983  Costa Rica      4397.433333
# 26199  Costa Rica       219.871667
# 27507  Costa Rica      1299.241667
# 29925  Costa Rica      1499.125000
#
#                                             EdLevel
# 264    college/university without bachelor's degree
# 20983                             Bachelor's degree
# 26199                             Bachelor's degree
# 27507  college/university without bachelor's degree
# 29925                             Bachelor's degree
#        Country  Monthly_Sal_EUR            EdLevel
# 323   Slovenia      1657.706093   Secondary school
# 1178  Slovenia      3288.530466  Bachelor's degree
# 3314  Slovenia      2464.157706    Master's degree
# 4028  Slovenia      3136.200717    Master's degree
# 4150  Slovenia      4480.286738  Bachelor's degree
#            Country  Monthly_Sal_EUR  \
# 331    El Salvador        59.965000
# 17242  El Salvador       999.416667
# 36302  El Salvador      1599.066667
# 44350  El Salvador      1918.880000
#
#                                             EdLevel
# 331                               Bachelor's degree
# 17242  college/university without bachelor's degree
# 36302  college/university without bachelor's degree
# 44350                               Master's degree
#        Country  Monthly_Sal_EUR            EdLevel
# 377   Portugal      3584.229391    Master's degree
# 916   Portugal      1030.465950  Bachelor's degree
# 3911  Portugal      1075.268817  Bachelor's degree
# 4488  Portugal      1693.548387  Bachelor's degree
# 4670  Portugal      1523.297491    Master's degree
#           Country  Monthly_Sal_EUR                    EdLevel
# 397   Switzerland      6192.308333  Primary/elementary school
# 626   Switzerland      8191.400000            Master's degree
# 712   Switzerland     13164.750000            Master's degree
# 1517  Switzerland     14627.500000            Master's degree
# 2140  Switzerland      7606.300000           Secondary school
#        Country  Monthly_Sal_EUR            EdLevel
# 427    Albania       716.845878  Bachelor's degree
# 4310   Albania     14336.917563    Master's degree
# 16059  Albania       752.688172  Bachelor's degree
# 21497  Albania       896.057348  Bachelor's degree
# 26853  Albania      7995.333333  Bachelor's degree
#       Country  Monthly_Sal_EUR                                       EdLevel
# 444   Austria      5197.132616                               Master's degree
# 876   Austria      3073.476703                             Bachelor's degree
# 1961  Austria      4139.784946                             Bachelor's degree
# 2193  Austria      8333.333333                             Bachelor's degree
# 3263  Austria      5645.161290  college/university without bachelor's degree
#       Country  Monthly_Sal_EUR                                       EdLevel
# 448   Romania      2150.537634                               Master's degree
# 1239  Romania       250.896057                               Master's degree
# 3175  Romania       116.487455                             Bachelor's degree
# 3954  Romania      1612.903226  college/university without bachelor's degree
# 4306  Romania      1792.114695                             Bachelor's degree
#      Country  Monthly_Sal_EUR                                       EdLevel
# 468   Sweden      3479.850113  college/university without bachelor's degree
# 1893  Sweden      2598.288084                             Bachelor's degree
# 3073  Sweden      4825.392157                               Master's degree
# 3223  Sweden      3201.462104                             Bachelor's degree
# 3746  Sweden      4094.982079                               Master's degree
#         Country  Monthly_Sal_EUR            EdLevel
# 13330    Peru        99.941667                           No formal education
# 34899    Peru       899.475000  college/university without bachelor's degree
# 43204    Peru      2358.623333                           Professional degree
#         Country  Monthly_Sal_EUR            EdLevel
# 12613  Zimbabwe        69.959167  Bachelor's degree
#           Country  Monthly_Sal_EUR  \
# 12875  Bangladesh       699.591667
# 13402  Bangladesh       499.708333
# 14235  Bangladesh       303.322958
# 21026  Bangladesh       649.620833
# 21649  Bangladesh      1499.125000
#
#                                             EdLevel
# 12875                             Bachelor's degree
# 13402  college/university without bachelor's degree
# 14235                             Bachelor's degree
# 21026                             Bachelor's degree
# 21649                             Bachelor's degree
#       Country  Monthly_Sal_EUR                                       EdLevel
# 12996   Malta      1971.326165                             Bachelor's degree
# 21935   Malta      2164.247312                             Bachelor's degree
# 21974   Malta      2150.537634                             Bachelor's degree
# 25817   Malta      1926.523297  college/university without bachelor's degree
# 26718   Malta      2419.354839  college/university without bachelor's degree
#       Country  Monthly_Sal_EUR                                       EdLevel
# 13080  Cyprus      4032.258065                             Bachelor's degree
# 18472  Cyprus      1281.362007                             Bachelor's degree
# 22590  Cyprus      2688.172043                             Bachelor's degree
# 49625  Cyprus      4435.483871  college/university without bachelor's degree
# 51378  Cyprus      8960.573477                              Secondary school
#          Country  Monthly_Sal_EUR            EdLevel
# 13240  Nicaragua      6496.208333  Bachelor's degree
#       Country  Monthly_Sal_EUR                                       EdLevel
# 13273  Jordan      1349.212500                             Bachelor's degree
# 13813  Jordan       149.912500                             Bachelor's degree
# 21491  Jordan      7195.800000                               Master's degree
# 26365  Jordan      1399.183333                             Bachelor's degree
# 33620  Jordan      3398.016667  college/university without bachelor's degree
#         Country  Monthly_Sal_EUR            EdLevel
# 14184  Honduras      1569.084167    Master's degree
# 27243  Honduras      1199.300000  Bachelor's degree
#       Country  Monthly_Sal_EUR            EdLevel
# 14497    Iraq           1199.3  Bachelor's degree
#        Country  Monthly_Sal_EUR            EdLevel
# 15280  Tunisia      1433.691756    Master's degree
# 16928  Tunisia        43.458781  Bachelor's degree
# 28582  Tunisia       599.650000  Bachelor's degree
# 38022  Tunisia       599.650000  Bachelor's degree
#         Country  Monthly_Sal_EUR            EdLevel
# 15975  Mongolia           599.65  Bachelor's degree
#       Country  Monthly_Sal_EUR                                       EdLevel
# 16016   Japan      5511.283208  college/university without bachelor's degree
# 23291   Japan     19544.572802                             Bachelor's degree
# 35441   Japan        76.223834                             Bachelor's degree
# 40569   Japan      3518.023104                             Bachelor's degree
# 46081   Japan      4690.697472                             Bachelor's degree
#       Country  Monthly_Sal_EUR                                       EdLevel
# 16528   Chile      4497.375000                             Bachelor's degree
# 17523   Chile       121.728950  college/university without bachelor's degree
# 24039   Chile      1998.833333                             Bachelor's degree
# 34089   Chile       999.416667  college/university without bachelor's degree
# 43500   Chile      2198.716667                           Professional degree
#           Country  Monthly_Sal_EUR            EdLevel
# 16706  Kyrgyzstan      1699.008333  Bachelor's degree
#            Country  Monthly_Sal_EUR            EdLevel
# 17318  Puerto Rico     17989.500000    Master's degree
# 17924  Puerto Rico      4797.200000  Bachelor's degree
# 23016  Puerto Rico      1998.833333  Bachelor's degree
# 48118  Puerto Rico      3997.666667  Bachelor's degree
#                       Country  Monthly_Sal_EUR          EdLevel
# 17431  New Caledonia (French)      2598.566308  Master's degree
# 31728  New Caledonia (French)      2508.960573  Master's degree
# 51220  New Caledonia (French)      4032.258065  Master's degree
#       Country  Monthly_Sal_EUR            EdLevel
# 17684   Zaire           479.72  Bachelor's degree
#          Country  Monthly_Sal_EUR            EdLevel
# 18020  Venezuela     15990.666667    Master's degree
# 23205  Venezuela      2398.600000   Secondary school
# 34627  Venezuela       399.766667  Bachelor's degree
# 41463  Venezuela        49.970833  Bachelor's degree
# 43227  Venezuela        39.976667  Bachelor's degree
#       Country  Monthly_Sal_EUR            EdLevel
# 18841   Ghana        57.366517  Bachelor's degree
# 42808   Ghana      9394.516667  Bachelor's degree
#        Country  Monthly_Sal_EUR                                       EdLevel
# 19754  Bolivia        99.941667                              Secondary school
# 31406  Bolivia       927.658550                             Bachelor's degree
# 41846  Bolivia      2998.250000  college/university without bachelor's degree
# 48361  Bolivia      1199.300000                             Bachelor's degree
#       Country  Monthly_Sal_EUR            EdLevel
# 19798  Taiwan       109.935833  Bachelor's degree
# 45853  Taiwan      3997.666667  Bachelor's degree
#        Country  Monthly_Sal_EUR            EdLevel
# 22782  Bahrain         7495.625  Bachelor's degree
#           Country  Monthly_Sal_EUR  \
# 23594  Seychelles      1399.183333
#
#                                             EdLevel
# 23594  college/university without bachelor's degree
#       Country  Monthly_Sal_EUR          EdLevel
# 24008  Guinea      6995.916667  Master's degree
#            Country  Monthly_Sal_EUR            EdLevel
# 26466  Philippines      2998.250000  Bachelor's degree
# 42644  Philippines       169.900833  Bachelor's degree
#           Country  Monthly_Sal_EUR  \
# 26727  Mozambique          1798.95
#
#                                             EdLevel
# 26727  college/university without bachelor's degree
#                 Country  Monthly_Sal_EUR          EdLevel
# 29336  Reunion (French)      4480.286738  Master's degree
#           Country  Monthly_Sal_EUR            EdLevel
# 29608  Montenegro       896.057348  Bachelor's degree
# 30948  Montenegro       860.215054  Bachelor's degree
#       Country  Monthly_Sal_EUR            EdLevel
# 29826    Guam      7875.403333  Bachelor's degree
#           Country  Monthly_Sal_EUR            EdLevel
# 32195  Kazakhstan        99.941667  Bachelor's degree
#         Country  Monthly_Sal_EUR            EdLevel
# 32625  Barbados          2998.25  Bachelor's degree
#         Country  Monthly_Sal_EUR            EdLevel
# 32647  Anguilla      9751.666667  Bachelor's degree
#           Country  Monthly_Sal_EUR          EdLevel
# 34321  Madagascar      2867.383513  Master's degree
#       Country  Monthly_Sal_EUR            EdLevel
# 35603   Syria       249.854167    Master's degree
# 39504   Syria       599.650000  Bachelor's degree
#          Country  Monthly_Sal_EUR  \
# 37276  Guatemala          4197.55
# 40383  Guatemala          5396.85
#
#                                             EdLevel
# 37276  college/university without bachelor's degree
# 40383                             Bachelor's degree
#         Country  Monthly_Sal_EUR          EdLevel
# 37879  Cambodia        49.970833  Master's degree
#           Country  Monthly_Sal_EUR            EdLevel
# 38043  Uzbekistan          5996.50    Master's degree
# 46333  Uzbekistan           239.86  Bachelor's degree
#                    Country  Monthly_Sal_EUR            EdLevel
# 38984  Martinique (French)       2087.81362  Bachelor's degree
#       Country  Monthly_Sal_EUR            EdLevel
# 39630   Yemen        99.941667  Bachelor's degree
#                     Country  Monthly_Sal_EUR  \
# 41710  Virgin Islands (USA)     17489.791667
#
#                                             EdLevel
# 41710  college/university without bachelor's degree
#         Country  Monthly_Sal_EUR           EdLevel
# 41917  Suriname           1199.3  Secondary school
#               Country  Monthly_Sal_EUR            EdLevel
# 41942  Cayman Islands      5728.356508  Bachelor's degree
#         Country  Monthly_Sal_EUR            EdLevel
# 43084  Botswana          1918.88  Bachelor's degree
#        Country  Monthly_Sal_EUR          EdLevel
# 43757  Iceland      6720.430108  Master's degree
#       Country  Monthly_Sal_EUR            EdLevel
# 46293  Uganda          11993.0  Bachelor's degree
#                            Country  Monthly_Sal_EUR          EdLevel
# 46411  U.S. Minor Outlying Islands     13592.066667  Master's degree
#         Country  Monthly_Sal_EUR            EdLevel
# 46662  Tanzania           599.65  Bachelor's degree
#       Country  Monthly_Sal_EUR            EdLevel
# 48365    Cuba        55.967333  Bachelor's degree
#            Country  Monthly_Sal_EUR            EdLevel
# 1   United Kingdom      7079.967608  Bachelor's degree
# 5   United Kingdom      4164.669192  Bachelor's degree
# 22  United Kingdom        41.975500  Bachelor's degree
# 79  United Kingdom      4511.766600  Bachelor's degree
# 82  United Kingdom      8259.978867    Master's degree
#           Country  Monthly_Sal_EUR  \
# 4    South Africa      2141.350150
# 120  South Africa      2866.327000
# 200  South Africa      3706.236767
# 356  South Africa       983.426000
# 550  South Africa     13991.833333
#
#                                           EdLevel
# 4    college/university without bachelor's degree
# 120                             Bachelor's degree
# 200  college/university without bachelor's degree
# 356                     Primary/elementary school
# 550                             Bachelor's degree
#           Country  Monthly_Sal_EUR  \
# 6   United States     11993.000000
# 23  United States      7495.625000
# 32  United States      4397.433333
# 33  United States      5996.500000
# 35  United States      7995.333333
#
#                                          EdLevel
# 6   college/university without bachelor's degree
# 23  college/university without bachelor's degree
# 32                             Bachelor's degree
# 33                             Bachelor's degree
# 35                             Bachelor's degree
#     Country  Monthly_Sal_EUR            EdLevel
# 17   Sweden      4787.605600    Master's degree
# 26   Sweden      7256.864358    Master's degree
# 116  Sweden      6359.088367  Bachelor's degree
# 136  Sweden      5535.968800    Master's degree
# 173  Sweden      5984.507000   Secondary school
#        Country  Monthly_Sal_EUR                                       EdLevel
# 20   Australia      9591.201867                             Bachelor's degree
# 142  Australia      5994.501167                               Master's degree
# 143  Australia      9191.535142                             Bachelor's degree
# 147  Australia      8791.968358  college/university without bachelor's degree
# 212  Australia      6154.407833                             Bachelor's degree
#    Country  Monthly_Sal_EUR                                       EdLevel
# 24   India      1095.160783                               Master's degree
# 41   India     12391.167600  college/university without bachelor's degree
# 45   India       657.216400                               Master's degree
# 93   India      3441.991000                               Master's degree
# 95   India       412.559200                             Bachelor's degree
#      Country  Monthly_Sal_EUR            EdLevel
# 25    Greece      5137.801200    Master's degree
# 195   Greece      7339.016408  Bachelor's degree
# 372   Greece      1247.272000    Master's degree
# 1267  Greece      1761.771700  Bachelor's degree
# 1421  Greece      4525.658492    Master's degree
#     Country  Monthly_Sal_EUR                                       EdLevel
degree
#       Country  Monthly_Sal_EUR            EdLevel
# 8692   Gambia      2998.250000   Secondary school
# 65677  Gambia      4997.083333  Bachelor's degree
#       Country  Monthly_Sal_EUR            EdLevel
# 8875    Ghana       399.766667  Bachelor's degree
# 9376    Ghana       310.818583  Bachelor's degree
# 13365   Ghana        12.492708    Master's degree
# 15995   Ghana       499.708333  Bachelor's degree
# 18641   Ghana        17.289908  Bachelor's degree
#                          Country  Monthly_Sal_EUR  \
# 8985   Congo, Republic of the...        31.981333
# 27889  Congo, Republic of the...      1798.950000
# 36676  Congo, Republic of the...      4997.083333
# 48135  Congo, Republic of the...     12492.708333
# 69284  Congo, Republic of the...        99.941667
#
#                                             EdLevel
# 8985   college/university without bachelor's degree
# 27889                             Bachelor's degree
# 36676                               Master's degree
# 48135                             Bachelor's degree
# 69284                             Bachelor's degree
#           Country  Monthly_Sal_EUR  \
# 9596   Mauritania       999.416667
# 69474  Mauritania      5996.500000
#
#                                             EdLevel
# 9596   college/university without bachelor's degree
# 69474  college/university without bachelor's degree
#                   Country  Monthly_Sal_EUR              EdLevel
# 9694   Hong Kong (S.A.R.)      5996.500000  Professional degree
# 10116  Hong Kong (S.A.R.)      1499.125000    Bachelor's degree
# 10407  Hong Kong (S.A.R.)       281.835500    Bachelor's degree
# 11015  Hong Kong (S.A.R.)      2198.716667    Bachelor's degree
# 12565  Hong Kong (S.A.R.)      3198.133333    Bachelor's degree
#            Country  Monthly_Sal_EUR            EdLevel
# 10525  South Korea       559.673333    Master's degree
# 18188  South Korea      7995.333333  Bachelor's degree
# 31662  South Korea      1499.125000     Something else
# 37761  South Korea       759.556667  Bachelor's degree
# 44346  South Korea      4997.083333  Bachelor's degree
#         Country  Monthly_Sal_EUR            EdLevel
# 10772  Cambodia        39.976667    Master's degree
# 20070  Cambodia       149.912500    Master's degree
# 39210  Cambodia     19988.333333   Associate degree
# 44472  Cambodia        39.976667  Bachelor's degree
# 54127  Cambodia        44.973750  Bachelor's degree
#           Country  Monthly_Sal_EUR            EdLevel
# 10792  Kyrgyzstan      8495.041667  Bachelor's degree
# 11629  Kyrgyzstan      7995.333333  Bachelor's degree
# 14315  Kyrgyzstan       249.854167   Secondary school
# 15531  Kyrgyzstan     12992.416667  Bachelor's degree
# 21079  Kyrgyzstan      3497.958333  Bachelor's degree
#           Country  Monthly_Sal_EUR            EdLevel
# 11293  Kazakhstan       399.766667  Bachelor's degree
# 15252  Kazakhstan     19988.333333  Bachelor's degree
# 25010  Kazakhstan     12492.708333  Bachelor's degree
# 27338  Kazakhstan      7795.450000  Bachelor's degree
# 37598  Kazakhstan     19988.333333  Bachelor's degree
#            Country  Monthly_Sal_EUR            EdLevel
# 11377  Afghanistan      6296.325000    Master's degree
# 14882  Afghanistan       649.620833  Bachelor's degree
# 17120  Afghanistan      1998.833333  Bachelor's degree
# 17486  Afghanistan      3497.958333  Bachelor's degree
# 31086  Afghanistan     15401.010833  Bachelor's degree
#       Country  Monthly_Sal_EUR                                       EdLevel
degree
#       Country  Monthly_Sal_EUR            EdLevel
# 19974   Benin        39.976667    Master's degree
# 74063   Benin     14991.250000  Bachelor's degree
# 83174   Benin        21.987167  Bachelor's degree
# 83435   Benin     19988.333333  Bachelor's degree
#       Country  Monthly_Sal_EUR            EdLevel
# 20639  Bhutan       199.883333  Bachelor's degree
# 59424  Bhutan      2998.250000  Bachelor's degree
#          Country  Monthly_Sal_EUR            EdLevel
# 21262  Palestine       269.842500  Bachelor's degree
# 28176  Palestine       539.685000  Bachelor's degree
# 32230  Palestine       149.912500  Bachelor's degree
# 33543  Palestine       469.725833  Bachelor's degree
# 39570  Palestine      2298.658333   Associate degree
#                  Country  Monthly_Sal_EUR           EdLevel
# 22032  Republic of Korea       379.778333  Associate degree
#          Country  Monthly_Sal_EUR  \
# 22053  Indonesia       449.737500
# 22371  Indonesia       199.883333
# 37522  Indonesia       249.854167
# 41431  Indonesia       349.795833
# 56896  Indonesia        34.979583
#
#                                             EdLevel
# 22053  college/university without bachelor's degree
# 22371                               Master's degree
# 37522  college/university without bachelor's degree
# 41431                             Bachelor's degree
# 56896  college/university without bachelor's degree
#           Country  Monthly_Sal_EUR            EdLevel
# 22592  Tajikistan      1499.125000  Bachelor's degree
# 48304  Tajikistan       699.591667  Bachelor's degree
# 73191  Tajikistan       199.883333  Bachelor's degree
#                            Country  Monthly_Sal_EUR  \
# 22676  United Republic of Tanzania      5996.500000
# 45768  United Republic of Tanzania      8495.041667
# 50520  United Republic of Tanzania      1998.833333
# 79228  United Republic of Tanzania      6995.916667
#
#                                             EdLevel
# 22676                             Bachelor's degree
# 45768                             Bachelor's degree
# 50520                             Bachelor's degree
# 79228  college/university without bachelor's degree
#           Country  Monthly_Sal_EUR            EdLevel
# 26106  Cape Verde        99.941667  Bachelor's degree
# 62121  Cape Verde      8095.275000  Bachelor's degree
#       Country  Monthly_Sal_EUR            EdLevel
# 26234    Oman       599.650000  Bachelor's degree
# 27672    Oman        99.941667  Bachelor's degree
# 30202    Oman        79.953333    Master's degree
# 64407    Oman       249.854167  Bachelor's degree
#       Country  Monthly_Sal_EUR                                       EdLevel
# 26833  Angola      8195.216667                             Bachelor's degree
# 28920  Angola       799.533333                             Bachelor's degree
# 37306  Angola      2998.250000                              Secondary school
# 53851  Angola         9.994167  college/university without bachelor's degree
# 72215  Angola     12992.416667  college/university without bachelor's degree
#       Country  Monthly_Sal_EUR            EdLevel
# 26881  Uganda        29.982500  Bachelor's degree
# 29425  Uganda       399.766667  Bachelor's degree
# 33799  Uganda       423.252958  Bachelor's degree
# 42184  Uganda       129.924167  Bachelor's degree
# 46839  Uganda       299.825000  Bachelor's degree
#                                 Country  Monthly_Sal_EUR            EdLevel
# 27438  Lao People's Democratic Republic       499.708333  Bachelor's degree
#         Country  Monthly_Sal_EUR            EdLevel
# 27472  Zimbabwe       299.825000   Associate degree
# 29070  Zimbabwe        59.965000  Bachelor's degree
# 29692  Zimbabwe        99.941667  Bachelor's degree
# 31652  Zimbabwe        29.982500  Bachelor's degree
# 39746  Zimbabwe        19.488625  Bachelor's degree
#               Country  Monthly_Sal_EUR  \
# 27936  CÃ´te d'Ivoire     14991.250000
# 28584  CÃ´te d'Ivoire        44.973750
# 71251  CÃ´te d'Ivoire      9994.166667
# 83176  CÃ´te d'Ivoire     14991.250000
#
#                                             EdLevel
# 27936  college/university without bachelor's degree
# 28584                               Master's degree
# 71251                                Something else
# 83176                               Master's degree
#        Country  Monthly_Sal_EUR          EdLevel
# 28062  Senegal         0.099942  Master's degree
# 75033  Senegal       479.720000  Master's degree
#        Country  Monthly_Sal_EUR            EdLevel
# 28164  Namibia      2698.425000  Bachelor's degree
# 31711  Namibia      3997.666667   Secondary school
# 32968  Namibia      3753.609117  Bachelor's degree
# 41714  Namibia      7995.333333  Bachelor's degree
# 43230  Namibia       319.813333  Bachelor's degree
#        Country  Monthly_Sal_EUR            EdLevel
# 28580  Lesotho         449.7375  Bachelor's degree
# 31311  Lesotho        1798.9500  Bachelor's degree
# 58149  Lesotho         599.6500  Bachelor's degree
#        Country  Monthly_Sal_EUR                                       EdLevel
# 30445  Jamaica     14991.250000  college/university without bachelor's degree
# 35890  Jamaica      9994.166667  college/university without bachelor's degree
# 36198  Jamaica     12992.416667  college/university without bachelor's degree
# 40964  Jamaica        39.976667  college/university without bachelor's degree
#        Country  Monthly_Sal_EUR           EdLevel
# 33043  Liberia        13.592067  Secondary school
#         Country  Monthly_Sal_EUR            EdLevel
# 35225  Suriname     19988.333333  Bachelor's degree
# 56645  Suriname       224.868750     Something else
#       Country  Monthly_Sal_EUR                                       EdLevel
# 36136   Niger      9094.691667  college/university without bachelor's degree
#         Country  Monthly_Sal_EUR            EdLevel
# 36627  Maldives      3997.666667  Bachelor's degree
# 40606  Maldives      1938.868333  Bachelor's degree
# 44032  Maldives      3997.666667  Bachelor's degree
# 48043  Maldives      1798.950000  Bachelor's degree
# 53378  Maldives       999.416667  Bachelor's degree
#           Country  Monthly_Sal_EUR  \
# 36801  Madagascar        62.963250
# 54411  Madagascar     19988.333333
# 55610  Madagascar      9994.166667
# 62506  Madagascar      9994.166667
#
#                                             EdLevel
# 36801                               Master's degree
# 54411  college/university without bachelor's degree
# 55610                             Bachelor's degree
# 62506                             Bachelor's degree
#            Country  Monthly_Sal_EUR  \
# 40207  Saint Lucia       219.871667
#
#                                             EdLevel
# 40207  college/university without bachelor's degree
#       Country  Monthly_Sal_EUR           EdLevel
# 47622  Guyana      7995.333333  Associate degree
#           Country  Monthly_Sal_EUR            EdLevel
# 49433  San Marino      4597.316667  Bachelor's degree
#           Country  Monthly_Sal_EUR            EdLevel
# 50190  Mozambique       684.600417  Bachelor's degree
# 54214  Mozambique      5896.558333  Bachelor's degree
# 82248  Mozambique      3497.958333   Secondary school
#       Country  Monthly_Sal_EUR          EdLevel
# 50252  Malawi     12747.859408  Master's degree
#       Country  Monthly_Sal_EUR            EdLevel
# 52551    Togo      9994.166667  Bachelor's degree
#                                 Country  Monthly_Sal_EUR  \
# 54468  Saint Vincent and the Grenadines           599.65
#
#                                             EdLevel
# 54468  college/university without bachelor's degree
#       Country  Monthly_Sal_EUR            EdLevel
# 67160    Fiji        69.959167  Bachelor's degree
#            Country  Monthly_Sal_EUR            EdLevel
# 77133  North Korea      1998.833333  Bachelor's degree

# %% [markdown]
# ### Compute a summary pdf - average of montly salaries per country

# %%
import codecs
import json
summary_df = None
i = 0
for year, df in clean_payment_dataframes_2017_to_2020.items():
    df = df.filter(items=['Country','Monthly_Sal_EUR'])
    
    df2 = df.copy(deep=True)
    
    # compute mean salary per country and reset the resulting df index
    df =  df.groupby('Country').mean().round(2).reset_index()
    
    # add column names 
    df.columns = ['Country', year]
    
    # merge the resulting dataframes into a single df columns = years, rows = countries
    if i > 0:
        summary_df = pd.DataFrame.merge(summary_df,df,on='Country')
        i+=1 
    else:
        summary_df =  df
        i+=1
        
    df2.columns = ['Country', 'respondentsCount']

    df2 = df2.groupby(by=['Country'] , as_index=False).count()
    
    print(df2.shape)
        
    print(df2.head())
    
    json_dict2 = {}
    for index, row in df2.iterrows():
        json_dict2[row["Country"]] = row["respondentsCount"]
  

    
  
    with codecs.open("processed_data/salaries/{}-income_respondents_count_per_country.json".format(year), "w", encoding='utf-8') as outfile:
        json.dump(json_dict2, outfile, indent = 4, ensure_ascii=False)

# Transpose the summary_df, now  columns = countries and rows = years 
summary_df = summary_df.T

# Pick all the countries -> first row of the transposed matrix
column_names = summary_df.iloc[0]
column_names = list(column_names) 

# drop the first row containing countries' names, instead make the countries the column names 
summary_df = summary_df.drop('Country')
summary_df.columns = column_names

# You can finally do some simple plots 
summary_df.plot( xticks = [2017, 2018, 2019, 2020, 2021], title= "A dirty plot of the world :P ")
summary_df[['Uzbekistan','France'] ].plot( xticks = [2017, 2018, 2019, 2020, 2021], title = "Uzbekistan vs. France ")
summary_df.to_json(path_or_buf = 'processed_data/salaries/average_montly_salary_in_Euros_per_country_per_year.json', index=True, indent = 4)

# %%
summary_df

# %%
df = clean_payment_dataframes_2017_to_2020[2017]
df[df.Monthly_Sal_EUR > max_montly_salary]

# %%
summary_df = None
i = 0
for year, df in clean_payment_dataframes_2017_to_2020.items():
    df = df.filter(items=['Country', 'YearsCodePro'] )
    print(df.head())
    # compute mean salary per country and reset the resulting df index
    df =  df.groupby('Country').mean().astype(int).reset_index()
    print(df.head())

    # add column names 
    df.columns = ['Country', year]
    
    # merge the resulting dataframes into a single df columns = years, rows = countries
    if i > 0:
        summary_df = pd.DataFrame.merge(summary_df,df,on='Country')
        i+=1 
    else:
        summary_df =  df
        i+=1

# Transpose the summary_df, now  columns = countries and rows = years 
summary_df = summary_df.T

# Pick all the countries -> first row of the transposed matrix
column_names = summary_df.iloc[0]
column_names = list(column_names) 

# drop the first row containing countries' names, instead make the countries the column names 
summary_df = summary_df.drop('Country')
summary_df.columns = column_names

# You can finally do some simple plots 
summary_df.plot( xticks = [2017, 2018, 2019, 2020, 2021], title= "A dirty plot of the world :P ")
summary_df[['Uzbekistan','France'] ].plot( xticks = [2017, 2018, 2019, 2020, 2021], title = "Uzbekistan vs. France ")

summary_df.to_json(path_or_buf = 'processed_data/experience/average_experience_per_country_per_year.json', index=True, indent=4)

# %%
summary_df
